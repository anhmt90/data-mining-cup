# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train=pd.read_csv('train.csv',sep='|')
test=pd.read_csv('test.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
# for training set

#train['totalScanTimeInMinutes'] = train['totalScanTimeInSeconds'] / 60.0
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
#rain['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
#train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
#train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
#train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
#train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
#train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']


# for test set

#train['totalScanTimeInMinutes'] = train['totalScanTimeInSeconds'] / 60.0
test['scannedLineItems'] = test['scannedLineItemsPerSecond'] * test['totalScanTimeInSeconds']
test['pricePerScannedLineItem'] = test['grandTotal'] / test['scannedLineItems']
test['scansWithoutRegistrationPerScannedLineItem'] = test['scansWithoutRegistration'] / test['scannedLineItems']
test['quantityModificationsPerScannedLineItem'] = test['quantityModifications'] / test['scannedLineItems']
test['lineItemVoidsPerSecond'] = test['lineItemVoids'] / test['totalScanTimeInSeconds']
#rain['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
#train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
#train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
#train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
#train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
#train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %% [markdown]
# # Larger training set due to rules found at Decision Tree Analysis

# %%
additional_no_frauds = test[test["trustLevel"] > 2.5]
additional_no_frauds = additional_no_frauds.assign(fraud = 0)

additional_frauds = test[(test["trustLevel"] < 1.5) &  (test["scannedLineItems"] > 20.5) & (test["valuePerSecond"] <= 0.118) & (test["scansWithoutRegistrationPerScannedLineItem"] > 0.168)]
additional_frauds = additional_frauds.assign(fraud = 1)


train = pd.concat([train, additional_no_frauds], ignore_index=True)
train = pd.concat([train, additional_frauds], ignore_index=True)

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    334270
# 1     12217
# Name: fraud, dtype: int64
# 0    0.96474
# 1    0.03526
# Name: fraud, dtype: float64

# %%
from sklearn.tree import ExtraTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm.classes import OneClassSVM
from sklearn.neural_network.multilayer_perceptron import MLPClassifier
from sklearn.neighbors.classification import RadiusNeighborsClassifier
from sklearn.neighbors.classification import KNeighborsClassifier
from sklearn.multioutput import ClassifierChain
from sklearn.multioutput import MultiOutputClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model.stochastic_gradient import SGDClassifier
from sklearn.linear_model.ridge import RidgeClassifierCV
from sklearn.linear_model.ridge import RidgeClassifier
from sklearn.linear_model.passive_aggressive import PassiveAggressiveClassifier
from sklearn.gaussian_process.gpc import GaussianProcessClassifier
from sklearn.ensemble.voting_classifier import VotingClassifier
from sklearn.ensemble.weight_boosting import AdaBoostClassifier
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
from sklearn.ensemble.bagging import BaggingClassifier
from sklearn.ensemble.forest import ExtraTreesClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import GaussianNB
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.svm import SVC
# from sklearn.mixture import DPGMM
#from sklearn.mixture import GMM
#from sklearn.mixture import GaussianMixture
#from sklearn.mixture import VBGMM



model_factory = [
# RandomForestRegressor(),
# XGBRegressor(nthread=1),
 #MLPRegressor(),
# Ridge(),
# BayesianRidge(),
# ExtraTreesRegressor(),
# ElasticNet(),
# KNeighborsRegressor(),
# GradientBoostingRegressor()
  ExtraTreeClassifier(),
    DecisionTreeClassifier(),
 #   OneClassSVM(),  # doesn't work instantly
    
                  # MLPClassifier(),# takes very long for a larger training set
    
 #   RadiusNeighborsClassifier(), # doesn't work instantly
    KNeighborsClassifier(),
#    ClassifierChain(),     # ensemble method
#    MultiOutputClassifier(), # ensemble method
#    OutputCodeClassifier(), # ensemble method
#    OneVsOneClassifier(), # ensemble method
#    OneVsRestClassifier(), # ensemble method
    SGDClassifier(),
    RidgeClassifierCV(),
    RidgeClassifier(),
    PassiveAggressiveClassifier(),
    
                   # GaussianProcessClassifier(),  # takes very long for a larger training set
    
#    VotingClassifier(), # ensemble method
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    BaggingClassifier(),
    ExtraTreesClassifier(),
    RandomForestClassifier(),
    BernoulliNB(),
  #  CalibratedClassifierCV(), # doesn't work instantly
    GaussianNB(), # causing some problems
 #   LabelPropagation(), # doesn't work instantly
 #   LabelSpreading(),  # doesn't work instantly
    LinearDiscriminantAnalysis(), # causing some problems
 #   LinearSVC(max_iter = 100000), # causing some problems
    LogisticRegression(max_iter = 10000),
    LogisticRegressionCV(max_iter = 10000),
    MultinomialNB(),
    NearestCentroid(),
  #  NuSVC(),   # doesn't work instantly
    Perceptron(),
    QuadraticDiscriminantAnalysis(),
     SVC(),
#    DPGMM(),
#    GMM(),
#    GaussianMixture(),
#    VBGMM()
]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer

def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)
loo = LeaveOneOut()

# %% [markdown]
# # Take a smaller sample for quicker training

# %%
train = train.sample(10000)

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    9661
# 1     339
# Name: fraud, dtype: int64
# 0    0.9661
# 1    0.0339
# Name: fraud, dtype: float64

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
len(list(X))
# Out:
# 14

# %%
import time

result_table = pd.DataFrame(columns=["Model", "Feature Count", "Features", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation"])


for feature_count in range(1,len(X)):

 for model in model_factory:
 
  t = time.time()
    
  best_features = SelectKBest(f_classif, k=feature_count).fit(X,Y)
  best_feature_list = X.columns[best_features.get_support()]

  X_selected_features = X[best_feature_list]
    
  print("Started " + model.__class__.__name__ + "with " + str(feature_count) + " features:" + best_feature_list)

  model.seed = 42

  scores = cross_val_score(model, X_selected_features, Y, cv=skf, scoring=my_custom_score)
  model_name = model.__class__.__name__
  score_mean = scores.mean()
  score_std = scores.std()

  print("Finished " + model.__class__.__name__ + " with " + str(feature_count) + " features:" + " after " + str(time.time() - t) + " seconds")
  print("Monetary Value Per Instance - Mean " + str(score_mean))
  print("Monetary Value Per Instance - Standard Deviation " + str(score_std))  
  print("")  
    
  result_table = result_table.append({
     "Model": model_name,
     "Feature Count": feature_count,
     "Features": best_feature_list,
     "Monetary Value Per Instance - Mean":  score_mean,
     "Monetary Value Per Instance - Standard Deviation": score_std
      }, ignore_index=True)

       
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Index(['Started ExtraTreeClassifierwith 1 features:trustLevel'], dtype='object')
# Finished ExtraTreeClassifierwith 1 features: after 0.03690147399902344 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started DecisionTreeClassifierwith 1 features:trustLevel'], dtype='object')
# Finished DecisionTreeClassifierwith 1 features: after 0.03291583061218262 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started KNeighborsClassifierwith 1 features:trustLevel'], dtype='object')
# Finished KNeighborsClassifierwith 1 features: after 0.4459857940673828 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started SGDClassifierwith 1 features:trustLevel'], dtype='object')
# Finished SGDClassifierwith 1 features: after 0.04590439796447754 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started RidgeClassifierCVwith 1 features:trustLevel'], dtype='object')
# Finished RidgeClassifierCVwith 1 features: after 0.08879995346069336 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierwith 1 features:trustLevel'], dtype='object')
# Finished RidgeClassifierwith 1 features: after 0.06881594657897949 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started PassiveAggressiveClassifierwith 1 features:trustLevel'], dtype='object')
# Finished PassiveAggressiveClassifierwith 1 features: after 0.08977603912353516 seconds
# Monetary Value Per Instance - Mean 0.1584995334995335
# Monetary Value Per Instance - Standard Deviation 0.015971215272743637
#
# Index(['Started AdaBoostClassifierwith 1 features:trustLevel'], dtype='object')
# Finished AdaBoostClassifierwith 1 features: after 0.8067722320556641 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started GradientBoostingClassifierwith 1 features:trustLevel'], dtype='object')
# Finished GradientBoostingClassifierwith 1 features: after 0.797753095626831 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started BaggingClassifierwith 1 features:trustLevel'], dtype='object')
# Finished BaggingClassifierwith 1 features: after 0.12369680404663086 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started ExtraTreesClassifierwith 1 features:trustLevel'], dtype='object')
# Finished ExtraTreesClassifierwith 1 features: after 0.11269688606262207 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started RandomForestClassifierwith 1 features:trustLevel'], dtype='object')
# Finished RandomForestClassifierwith 1 features: after 0.12890386581420898 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started BernoulliNBwith 1 features:trustLevel'], dtype='object')
# Finished BernoulliNBwith 1 features: after 0.03699302673339844 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started GaussianNBwith 1 features:trustLevel'], dtype='object')
# Finished GaussianNBwith 1 features: after 0.03291058540344238 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started LinearDiscriminantAnalysiswith 1 features:trustLevel'], dtype='object')
# Finished LinearDiscriminantAnalysiswith 1 features: after 0.04188823699951172 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started LogisticRegressionwith 1 features:trustLevel'], dtype='object')
# Finished LogisticRegressionwith 1 features: after 0.07479977607727051 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started LogisticRegressionCVwith 1 features:trustLevel'], dtype='object')
# Finished LogisticRegressionCVwith 1 features: after 1.0309944152832031 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started MultinomialNBwith 1 features:trustLevel'], dtype='object')
# Finished MultinomialNBwith 1 features: after 0.03789877891540527 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started NearestCentroidwith 1 features:trustLevel'], dtype='object')
# Finished NearestCentroidwith 1 features: after 0.034912109375 seconds
# Monetary Value Per Instance - Mean 0.1344995334995335
# Monetary Value Per Instance - Standard Deviation 0.024840638584101
#
# Index(['Started Perceptronwith 1 features:trustLevel'], dtype='object')
# Finished Perceptronwith 1 features: after 0.04787015914916992 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started QuadraticDiscriminantAnalysiswith 1 features:trustLevel'], dtype='object')
# Finished QuadraticDiscriminantAnalysiswith 1 features: after 0.03390932083129883 seconds
# Monetary Value Per Instance - Mean -2.2530004665004664
# Monetary Value Per Instance - Standard Deviation 7.242341374154186
#
# Index(['Started SVCwith 1 features:trustLevel'], dtype='object')
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:720: RuntimeWarning: invalid value encountered in add
#   return (-0.5 * (norm2 + u) + np.log(self.priors_))
# Finished SVCwith 1 features: after 0.11970925331115723 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started ExtraTreeClassifierwith 2 features:scannedLineItems', 'Started ExtraTreeClassifierwith 2 features:trustLevel'], dtype='object')
# Finished ExtraTreeClassifierwith 2 features: after 0.03490567207336426 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started DecisionTreeClassifierwith 2 features:scannedLineItems', 'Started DecisionTreeClassifierwith 2 features:trustLevel'], dtype='object')
# Finished DecisionTreeClassifierwith 2 features: after 0.04102826118469238 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started KNeighborsClassifierwith 2 features:scannedLineItems', 'Started KNeighborsClassifierwith 2 features:trustLevel'], dtype='object')
# Finished KNeighborsClassifierwith 2 features: after 0.21467375755310059 seconds
# Monetary Value Per Instance - Mean 0.1644995334995335
# Monetary Value Per Instance - Standard Deviation 0.01490252714454557
#
# Index(['Started SGDClassifierwith 2 features:scannedLineItems', 'Started SGDClassifierwith 2 features:trustLevel'], dtype='object')
# Finished SGDClassifierwith 2 features: after 0.04989433288574219 seconds
# Monetary Value Per Instance - Mean 0.12796650046650046
# Monetary Value Per Instance - Standard Deviation 0.0989406720980568
#
# Index(['Started RidgeClassifierCVwith 2 features:scannedLineItems', 'Started RidgeClassifierCVwith 2 features:trustLevel'], dtype='object')
# Finished RidgeClassifierCVwith 2 features: after 0.057843685150146484 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierwith 2 features:scannedLineItems', 'Started RidgeClassifierwith 2 features:trustLevel'], dtype='object')
# Finished RidgeClassifierwith 2 features: after 0.05285906791687012 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started PassiveAggressiveClassifierwith 2 features:scannedLineItems', 'Started PassiveAggressiveClassifierwith 2 features:trustLevel'], dtype='object')
# Finished PassiveAggressiveClassifierwith 2 features: after 0.0548553466796875 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started AdaBoostClassifierwith 2 features:scannedLineItems', 'Started AdaBoostClassifierwith 2 features:trustLevel'], dtype='object')
# Finished AdaBoostClassifierwith 2 features: after 0.9470560550689697 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started GradientBoostingClassifierwith 2 features:scannedLineItems', 'Started GradientBoostingClassifierwith 2 features:trustLevel'], dtype='object')
# Finished GradientBoostingClassifierwith 2 features: after 0.9935474395751953 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started BaggingClassifierwith 2 features:scannedLineItems', 'Started BaggingClassifierwith 2 features:trustLevel'], dtype='object')
# Finished BaggingClassifierwith 2 features: after 0.14801406860351562 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started ExtraTreesClassifierwith 2 features:scannedLineItems', 'Started ExtraTreesClassifierwith 2 features:trustLevel'], dtype='object')
# Finished ExtraTreesClassifierwith 2 features: after 0.12003326416015625 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started RandomForestClassifierwith 2 features:scannedLineItems', 'Started RandomForestClassifierwith 2 features:trustLevel'], dtype='object')
# Finished RandomForestClassifierwith 2 features: after 0.14037203788757324 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.015615122471202465
#
# Index(['Started BernoulliNBwith 2 features:scannedLineItems', 'Started BernoulliNBwith 2 features:trustLevel'], dtype='object')
# Finished BernoulliNBwith 2 features: after 0.03792619705200195 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started GaussianNBwith 2 features:scannedLineItems', 'Started GaussianNBwith 2 features:trustLevel'], dtype='object')
# Finished GaussianNBwith 2 features: after 0.03692960739135742 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LinearDiscriminantAnalysiswith 2 features:scannedLineItems', 'Started LinearDiscriminantAnalysiswith 2 features:trustLevel'], dtype='object')
# Finished LinearDiscriminantAnalysiswith 2 features: after 0.0583491325378418 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.010901011411362349
#
# Index(['Started LogisticRegressionwith 2 features:scannedLineItems', 'Started LogisticRegressionwith 2 features:trustLevel'], dtype='object')
# Finished LogisticRegressionwith 2 features: after 0.09827280044555664 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started LogisticRegressionCVwith 2 features:scannedLineItems', 'Started LogisticRegressionCVwith 2 features:trustLevel'], dtype='object')
# Finished LogisticRegressionCVwith 2 features: after 2.3708789348602295 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started MultinomialNBwith 2 features:scannedLineItems', 'Started MultinomialNBwith 2 features:trustLevel'], dtype='object')
# Finished MultinomialNBwith 2 features: after 0.04838109016418457 seconds
# Monetary Value Per Instance - Mean 0.0574965124965125
# Monetary Value Per Instance - Standard Deviation 0.01912533859811617
#
# Index(['Started NearestCentroidwith 2 features:scannedLineItems', 'Started NearestCentroidwith 2 features:trustLevel'], dtype='object')
# Finished NearestCentroidwith 2 features: after 0.03491067886352539 seconds
# Monetary Value Per Instance - Mean -7.4829870264870255
# Monetary Value Per Instance - Standard Deviation 0.3818277514629321
#
# Index(['Started Perceptronwith 2 features:scannedLineItems', 'Started Perceptronwith 2 features:trustLevel'], dtype='object')
# Finished Perceptronwith 2 features: after 0.04838299751281738 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started QuadraticDiscriminantAnalysiswith 2 features:scannedLineItems', 'Started QuadraticDiscriminantAnalysiswith 2 features:trustLevel'], dtype='object')
# Finished QuadraticDiscriminantAnalysiswith 2 features: after 0.037427663803100586 seconds
# Monetary Value Per Instance - Mean -2.248000466500466
# Monetary Value Per Instance - Standard Deviation 7.244003629516659
#
# Index(['Started SVCwith 2 features:scannedLineItems', 'Started SVCwith 2 features:trustLevel'], dtype='object')
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# Finished SVCwith 2 features: after 0.4090726375579834 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.015615122471202465
#
# Index(['Started ExtraTreeClassifierwith 3 features:scannedLineItems',
#        'Started ExtraTreeClassifierwith 3 features:scansWithoutRegistration',
#        'Started ExtraTreeClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreeClassifierwith 3 features: after 0.03796792030334473 seconds
# Monetary Value Per Instance - Mean 0.16449953349953347
# Monetary Value Per Instance - Standard Deviation 0.009853188077668955
#
# Index(['Started DecisionTreeClassifierwith 3 features:scannedLineItems',
#        'Started DecisionTreeClassifierwith 3 features:scansWithoutRegistration',
#        'Started DecisionTreeClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished DecisionTreeClassifierwith 3 features: after 0.041975975036621094 seconds
# Monetary Value Per Instance - Mean 0.1609995334995335
# Monetary Value Per Instance - Standard Deviation 0.01090101141136235
#
# Index(['Started KNeighborsClassifierwith 3 features:scannedLineItems',
#        'Started KNeighborsClassifierwith 3 features:scansWithoutRegistration',
#        'Started KNeighborsClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished KNeighborsClassifierwith 3 features: after 0.21620678901672363 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started SGDClassifierwith 3 features:scannedLineItems',
#        'Started SGDClassifierwith 3 features:scansWithoutRegistration',
#        'Started SGDClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished SGDClassifierwith 3 features: after 0.05088996887207031 seconds
# Monetary Value Per Instance - Mean 0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierCVwith 3 features:scannedLineItems',
#        'Started RidgeClassifierCVwith 3 features:scansWithoutRegistration',
#        'Started RidgeClassifierCVwith 3 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierCVwith 3 features: after 0.052858591079711914 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierwith 3 features:scannedLineItems',
#        'Started RidgeClassifierwith 3 features:scansWithoutRegistration',
#        'Started RidgeClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierwith 3 features: after 0.09275054931640625 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started PassiveAggressiveClassifierwith 3 features:scannedLineItems',
#        'Started PassiveAggressiveClassifierwith 3 features:scansWithoutRegistration',
#        'Started PassiveAggressiveClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished PassiveAggressiveClassifierwith 3 features: after 0.09973287582397461 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started AdaBoostClassifierwith 3 features:scannedLineItems',
#        'Started AdaBoostClassifierwith 3 features:scansWithoutRegistration',
#        'Started AdaBoostClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished AdaBoostClassifierwith 3 features: after 1.0281016826629639 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.014835241228001136
#
# Index(['Started GradientBoostingClassifierwith 3 features:scannedLineItems',
#        'Started GradientBoostingClassifierwith 3 features:scansWithoutRegistration',
#        'Started GradientBoostingClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished GradientBoostingClassifierwith 3 features: after 1.119663953781128 seconds
# Monetary Value Per Instance - Mean 0.1559995334995335
# Monetary Value Per Instance - Standard Deviation 0.015931961109229058
#
# Index(['Started BaggingClassifierwith 3 features:scannedLineItems',
#        'Started BaggingClassifierwith 3 features:scansWithoutRegistration',
#        'Started BaggingClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished BaggingClassifierwith 3 features: after 0.1616809368133545 seconds
# Monetary Value Per Instance - Mean 0.15849953349953347
# Monetary Value Per Instance - Standard Deviation 0.015971215272743637
#
# Index(['Started ExtraTreesClassifierwith 3 features:scannedLineItems',
#        'Started ExtraTreesClassifierwith 3 features:scansWithoutRegistration',
#        'Started ExtraTreesClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreesClassifierwith 3 features: after 0.12669038772583008 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started RandomForestClassifierwith 3 features:scannedLineItems',
#        'Started RandomForestClassifierwith 3 features:scansWithoutRegistration',
#        'Started RandomForestClassifierwith 3 features:trustLevel'],
#       dtype='object')
# Finished RandomForestClassifierwith 3 features: after 0.14421296119689941 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started BernoulliNBwith 3 features:scannedLineItems',
#        'Started BernoulliNBwith 3 features:scansWithoutRegistration',
#        'Started BernoulliNBwith 3 features:trustLevel'],
#       dtype='object')
# Finished BernoulliNBwith 3 features: after 0.03992104530334473 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started GaussianNBwith 3 features:scannedLineItems',
#        'Started GaussianNBwith 3 features:scansWithoutRegistration',
#        'Started GaussianNBwith 3 features:trustLevel'],
#       dtype='object')
# Finished GaussianNBwith 3 features: after 0.03892350196838379 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started LinearDiscriminantAnalysiswith 3 features:scannedLineItems',
#        'Started LinearDiscriminantAnalysiswith 3 features:scansWithoutRegistration',
#        'Started LinearDiscriminantAnalysiswith 3 features:trustLevel'],
#       dtype='object')
# Finished LinearDiscriminantAnalysiswith 3 features: after 0.056874990463256836 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started LogisticRegressionwith 3 features:scannedLineItems',
#        'Started LogisticRegressionwith 3 features:scansWithoutRegistration',
#        'Started LogisticRegressionwith 3 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionwith 3 features: after 0.10870814323425293 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LogisticRegressionCVwith 3 features:scannedLineItems',
#        'Started LogisticRegressionCVwith 3 features:scansWithoutRegistration',
#        'Started LogisticRegressionCVwith 3 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionCVwith 3 features: after 2.85848069190979 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started MultinomialNBwith 3 features:scannedLineItems',
#        'Started MultinomialNBwith 3 features:scansWithoutRegistration',
#        'Started MultinomialNBwith 3 features:trustLevel'],
#       dtype='object')
# Finished MultinomialNBwith 3 features: after 0.03690147399902344 seconds
# Monetary Value Per Instance - Mean 0.057498514498514494
# Monetary Value Per Instance - Standard Deviation 0.020639501377199724
#
# Index(['Started NearestCentroidwith 3 features:scannedLineItems',
#        'Started NearestCentroidwith 3 features:scansWithoutRegistration',
#        'Started NearestCentroidwith 3 features:trustLevel'],
#       dtype='object')
# Finished NearestCentroidwith 3 features: after 0.034426212310791016 seconds
# Monetary Value Per Instance - Mean -7.220486946486946
# Monetary Value Per Instance - Standard Deviation 0.3446195850680205
#
# Index(['Started Perceptronwith 3 features:scannedLineItems',
#        'Started Perceptronwith 3 features:scansWithoutRegistration',
#        'Started Perceptronwith 3 features:trustLevel'],
#       dtype='object')
# Finished Perceptronwith 3 features: after 0.04787182807922363 seconds
# Monetary Value Per Instance - Mean 0.13203349953349952
# Monetary Value Per Instance - Standard Deviation 0.10090508826513875
#
# Index(['Started QuadraticDiscriminantAnalysiswith 3 features:scannedLineItems',
#        'Started QuadraticDiscriminantAnalysiswith 3 features:scansWithoutRegistration',
#        'Started QuadraticDiscriminantAnalysiswith 3 features:trustLevel'],
#       dtype='object')
# Finished QuadraticDiscriminantAnalysiswith 3 features: after 0.03790020942687988 seconds
# Monetary Value Per Instance - Mean -2.248000466500466
# Monetary Value Per Instance - Standard Deviation 7.244003629516659
#
# Index(['Started SVCwith 3 features:scannedLineItems',
#        'Started SVCwith 3 features:scansWithoutRegistration',
#        'Started SVCwith 3 features:trustLevel'],
#       dtype='object')
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# Finished SVCwith 3 features: after 1.8903284072875977 seconds
# Monetary Value Per Instance - Mean 0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started ExtraTreeClassifierwith 4 features:pricePerScannedLineItem',
#        'Started ExtraTreeClassifierwith 4 features:scannedLineItems',
#        'Started ExtraTreeClassifierwith 4 features:scansWithoutRegistration',
#        'Started ExtraTreeClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreeClassifierwith 4 features: after 0.03399848937988281 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started DecisionTreeClassifierwith 4 features:pricePerScannedLineItem',
#        'Started DecisionTreeClassifierwith 4 features:scannedLineItems',
#        'Started DecisionTreeClassifierwith 4 features:scansWithoutRegistration',
#        'Started DecisionTreeClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished DecisionTreeClassifierwith 4 features: after 0.0529170036315918 seconds
# Monetary Value Per Instance - Mean 0.15849953349953347
# Monetary Value Per Instance - Standard Deviation 0.015971215272743637
#
# Index(['Started KNeighborsClassifierwith 4 features:pricePerScannedLineItem',
#        'Started KNeighborsClassifierwith 4 features:scannedLineItems',
#        'Started KNeighborsClassifierwith 4 features:scansWithoutRegistration',
#        'Started KNeighborsClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished KNeighborsClassifierwith 4 features: after 0.23995471000671387 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started SGDClassifierwith 4 features:pricePerScannedLineItem',
#        'Started SGDClassifierwith 4 features:scannedLineItems',
#        'Started SGDClassifierwith 4 features:scansWithoutRegistration',
#        'Started SGDClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished SGDClassifierwith 4 features: after 0.05089068412780762 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started RidgeClassifierCVwith 4 features:pricePerScannedLineItem',
#        'Started RidgeClassifierCVwith 4 features:scannedLineItems',
#        'Started RidgeClassifierCVwith 4 features:scansWithoutRegistration',
#        'Started RidgeClassifierCVwith 4 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierCVwith 4 features: after 0.06485366821289062 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierwith 4 features:pricePerScannedLineItem',
#        'Started RidgeClassifierwith 4 features:scannedLineItems',
#        'Started RidgeClassifierwith 4 features:scansWithoutRegistration',
#        'Started RidgeClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierwith 4 features: after 0.050863027572631836 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started PassiveAggressiveClassifierwith 4 features:pricePerScannedLineItem',
#        'Started PassiveAggressiveClassifierwith 4 features:scannedLineItems',
#        'Started PassiveAggressiveClassifierwith 4 features:scansWithoutRegistration',
#        'Started PassiveAggressiveClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished PassiveAggressiveClassifierwith 4 features: after 0.06283187866210938 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started AdaBoostClassifierwith 4 features:pricePerScannedLineItem',
#        'Started AdaBoostClassifierwith 4 features:scannedLineItems',
#        'Started AdaBoostClassifierwith 4 features:scansWithoutRegistration',
#        'Started AdaBoostClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished AdaBoostClassifierwith 4 features: after 1.346895456314087 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.014835241228001136
#
# Index(['Started GradientBoostingClassifierwith 4 features:pricePerScannedLineItem',
#        'Started GradientBoostingClassifierwith 4 features:scannedLineItems',
#        'Started GradientBoostingClassifierwith 4 features:scansWithoutRegistration',
#        'Started GradientBoostingClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished GradientBoostingClassifierwith 4 features: after 0.9779400825500488 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started BaggingClassifierwith 4 features:pricePerScannedLineItem',
#        'Started BaggingClassifierwith 4 features:scannedLineItems',
#        'Started BaggingClassifierwith 4 features:scansWithoutRegistration',
#        'Started BaggingClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished BaggingClassifierwith 4 features: after 0.2244272232055664 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started ExtraTreesClassifierwith 4 features:pricePerScannedLineItem',
#        'Started ExtraTreesClassifierwith 4 features:scannedLineItems',
#        'Started ExtraTreesClassifierwith 4 features:scansWithoutRegistration',
#        'Started ExtraTreesClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreesClassifierwith 4 features: after 0.13296794891357422 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started RandomForestClassifierwith 4 features:pricePerScannedLineItem',
#        'Started RandomForestClassifierwith 4 features:scannedLineItems',
#        'Started RandomForestClassifierwith 4 features:scansWithoutRegistration',
#        'Started RandomForestClassifierwith 4 features:trustLevel'],
#       dtype='object')
# Finished RandomForestClassifierwith 4 features: after 0.18505001068115234 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started BernoulliNBwith 4 features:pricePerScannedLineItem',
#        'Started BernoulliNBwith 4 features:scannedLineItems',
#        'Started BernoulliNBwith 4 features:scansWithoutRegistration',
#        'Started BernoulliNBwith 4 features:trustLevel'],
#       dtype='object')
# Finished BernoulliNBwith 4 features: after 0.03989219665527344 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started GaussianNBwith 4 features:pricePerScannedLineItem',
#        'Started GaussianNBwith 4 features:scannedLineItems',
#        'Started GaussianNBwith 4 features:scansWithoutRegistration',
#        'Started GaussianNBwith 4 features:trustLevel'],
#       dtype='object')
# Finished GaussianNBwith 4 features: after 0.038904666900634766 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LinearDiscriminantAnalysiswith 4 features:pricePerScannedLineItem',
#        'Started LinearDiscriminantAnalysiswith 4 features:scannedLineItems',
#        'Started LinearDiscriminantAnalysiswith 4 features:scansWithoutRegistration',
#        'Started LinearDiscriminantAnalysiswith 4 features:trustLevel'],
#       dtype='object')
# Finished LinearDiscriminantAnalysiswith 4 features: after 0.06284093856811523 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LogisticRegressionwith 4 features:pricePerScannedLineItem',
#        'Started LogisticRegressionwith 4 features:scannedLineItems',
#        'Started LogisticRegressionwith 4 features:scansWithoutRegistration',
#        'Started LogisticRegressionwith 4 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionwith 4 features: after 0.16216015815734863 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LogisticRegressionCVwith 4 features:pricePerScannedLineItem',
#        'Started LogisticRegressionCVwith 4 features:scannedLineItems',
#        'Started LogisticRegressionCVwith 4 features:scansWithoutRegistration',
#        'Started LogisticRegressionCVwith 4 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionCVwith 4 features: after 3.1943440437316895 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started MultinomialNBwith 4 features:pricePerScannedLineItem',
#        'Started MultinomialNBwith 4 features:scannedLineItems',
#        'Started MultinomialNBwith 4 features:scansWithoutRegistration',
#        'Started MultinomialNBwith 4 features:trustLevel'],
#       dtype='object')
# Finished MultinomialNBwith 4 features: after 0.0364227294921875 seconds
# Monetary Value Per Instance - Mean -1.6725458465458467
# Monetary Value Per Instance - Standard Deviation 0.19484619273524903
#
# Index(['Started NearestCentroidwith 4 features:pricePerScannedLineItem',
#        'Started NearestCentroidwith 4 features:scannedLineItems',
#        'Started NearestCentroidwith 4 features:scansWithoutRegistration',
#        'Started NearestCentroidwith 4 features:trustLevel'],
#       dtype='object')
# Finished NearestCentroidwith 4 features: after 0.07081103324890137 seconds
# Monetary Value Per Instance - Mean -7.940464608964611
# Monetary Value Per Instance - Standard Deviation 0.4187511017465536
#
# Index(['Started Perceptronwith 4 features:pricePerScannedLineItem',
#        'Started Perceptronwith 4 features:scannedLineItems',
#        'Started Perceptronwith 4 features:scansWithoutRegistration',
#        'Started Perceptronwith 4 features:trustLevel'],
#       dtype='object')
# Finished Perceptronwith 4 features: after 0.060837507247924805 seconds
# Monetary Value Per Instance - Mean 0.1619995334995335
# Monetary Value Per Instance - Standard Deviation 0.011217530155590632
#
# Index(['Started QuadraticDiscriminantAnalysiswith 4 features:pricePerScannedLineItem',
#        'Started QuadraticDiscriminantAnalysiswith 4 features:scannedLineItems',
#        'Started QuadraticDiscriminantAnalysiswith 4 features:scansWithoutRegistration',
#        'Started QuadraticDiscriminantAnalysiswith 4 features:trustLevel'],
#       dtype='object')
# Finished QuadraticDiscriminantAnalysiswith 4 features: after 0.04540657997131348 seconds
# Monetary Value Per Instance - Mean -2.248000466500466
# Monetary Value Per Instance - Standard Deviation 7.244003629516659
#
# Index(['Started SVCwith 4 features:pricePerScannedLineItem',
#        'Started SVCwith 4 features:scannedLineItems',
#        'Started SVCwith 4 features:scansWithoutRegistration',
#        'Started SVCwith 4 features:trustLevel'],
#       dtype='object')
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: invalid value encountered in multiply
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# Finished SVCwith 4 features: after 4.085506439208984 seconds
# Monetary Value Per Instance - Mean 0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started ExtraTreeClassifierwith 5 features:pricePerScannedLineItem',
#        'Started ExtraTreeClassifierwith 5 features:scannedLineItems',
#        'Started ExtraTreeClassifierwith 5 features:scansWithoutRegistration',
#        'Started ExtraTreeClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started ExtraTreeClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreeClassifierwith 5 features: after 0.03692960739135742 seconds
# Monetary Value Per Instance - Mean 0.1479985324985325
# Monetary Value Per Instance - Standard Deviation 0.018854051391074534
#
# Index(['Started DecisionTreeClassifierwith 5 features:pricePerScannedLineItem',
#        'Started DecisionTreeClassifierwith 5 features:scannedLineItems',
#        'Started DecisionTreeClassifierwith 5 features:scansWithoutRegistration',
#        'Started DecisionTreeClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started DecisionTreeClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished DecisionTreeClassifierwith 5 features: after 0.06286263465881348 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started KNeighborsClassifierwith 5 features:pricePerScannedLineItem',
#        'Started KNeighborsClassifierwith 5 features:scannedLineItems',
#        'Started KNeighborsClassifierwith 5 features:scansWithoutRegistration',
#        'Started KNeighborsClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started KNeighborsClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished KNeighborsClassifierwith 5 features: after 0.234527587890625 seconds
# Monetary Value Per Instance - Mean -0.179488036988037
# Monetary Value Per Instance - Standard Deviation 0.03677889687659031
#
# Index(['Started SGDClassifierwith 5 features:pricePerScannedLineItem',
#        'Started SGDClassifierwith 5 features:scannedLineItems',
#        'Started SGDClassifierwith 5 features:scansWithoutRegistration',
#        'Started SGDClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started SGDClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished SGDClassifierwith 5 features: after 0.052886009216308594 seconds
# Monetary Value Per Instance - Mean -0.33900104000104003
# Monetary Value Per Instance - Standard Deviation 0.2405496183635578
#
# Index(['Started RidgeClassifierCVwith 5 features:pricePerScannedLineItem',
#        'Started RidgeClassifierCVwith 5 features:scannedLineItems',
#        'Started RidgeClassifierCVwith 5 features:scansWithoutRegistration',
#        'Started RidgeClassifierCVwith 5 features:totalScanTimeInSeconds',
#        'Started RidgeClassifierCVwith 5 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierCVwith 5 features: after 0.11668515205383301 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started RidgeClassifierwith 5 features:pricePerScannedLineItem',
#        'Started RidgeClassifierwith 5 features:scannedLineItems',
#        'Started RidgeClassifierwith 5 features:scansWithoutRegistration',
#        'Started RidgeClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started RidgeClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished RidgeClassifierwith 5 features: after 0.05186152458190918 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started PassiveAggressiveClassifierwith 5 features:pricePerScannedLineItem',
#        'Started PassiveAggressiveClassifierwith 5 features:scannedLineItems',
#        'Started PassiveAggressiveClassifierwith 5 features:scansWithoutRegistration',
#        'Started PassiveAggressiveClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started PassiveAggressiveClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished PassiveAggressiveClassifierwith 5 features: after 0.08979129791259766 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started AdaBoostClassifierwith 5 features:pricePerScannedLineItem',
#        'Started AdaBoostClassifierwith 5 features:scannedLineItems',
#        'Started AdaBoostClassifierwith 5 features:scansWithoutRegistration',
#        'Started AdaBoostClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started AdaBoostClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished AdaBoostClassifierwith 5 features: after 1.613257884979248 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.014835241228001136
#
# Index(['Started GradientBoostingClassifierwith 5 features:pricePerScannedLineItem',
#        'Started GradientBoostingClassifierwith 5 features:scannedLineItems',
#        'Started GradientBoostingClassifierwith 5 features:scansWithoutRegistration',
#        'Started GradientBoostingClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started GradientBoostingClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished GradientBoostingClassifierwith 5 features: after 1.054877758026123 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started BaggingClassifierwith 5 features:pricePerScannedLineItem',
#        'Started BaggingClassifierwith 5 features:scannedLineItems',
#        'Started BaggingClassifierwith 5 features:scansWithoutRegistration',
#        'Started BaggingClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started BaggingClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished BaggingClassifierwith 5 features: after 0.2705850601196289 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started ExtraTreesClassifierwith 5 features:pricePerScannedLineItem',
#        'Started ExtraTreesClassifierwith 5 features:scannedLineItems',
#        'Started ExtraTreesClassifierwith 5 features:scansWithoutRegistration',
#        'Started ExtraTreesClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started ExtraTreesClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished ExtraTreesClassifierwith 5 features: after 0.1391894817352295 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started RandomForestClassifierwith 5 features:pricePerScannedLineItem',
#        'Started RandomForestClassifierwith 5 features:scannedLineItems',
#        'Started RandomForestClassifierwith 5 features:scansWithoutRegistration',
#        'Started RandomForestClassifierwith 5 features:totalScanTimeInSeconds',
#        'Started RandomForestClassifierwith 5 features:trustLevel'],
#       dtype='object')
# Finished RandomForestClassifierwith 5 features: after 0.20462799072265625 seconds
# Monetary Value Per Instance - Mean 0.16849953349953348
# Monetary Value Per Instance - Standard Deviation 0.003176326069163795
#
# Index(['Started BernoulliNBwith 5 features:pricePerScannedLineItem',
#        'Started BernoulliNBwith 5 features:scannedLineItems',
#        'Started BernoulliNBwith 5 features:scansWithoutRegistration',
#        'Started BernoulliNBwith 5 features:totalScanTimeInSeconds',
#        'Started BernoulliNBwith 5 features:trustLevel'],
#       dtype='object')
# Finished BernoulliNBwith 5 features: after 0.04191279411315918 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
#
# Index(['Started GaussianNBwith 5 features:pricePerScannedLineItem',
#        'Started GaussianNBwith 5 features:scannedLineItems',
#        'Started GaussianNBwith 5 features:scansWithoutRegistration',
#        'Started GaussianNBwith 5 features:totalScanTimeInSeconds',
#        'Started GaussianNBwith 5 features:trustLevel'],
#       dtype='object')
# Finished GaussianNBwith 5 features: after 0.039893388748168945 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started LinearDiscriminantAnalysiswith 5 features:pricePerScannedLineItem',
#        'Started LinearDiscriminantAnalysiswith 5 features:scannedLineItems',
#        'Started LinearDiscriminantAnalysiswith 5 features:scansWithoutRegistration',
#        'Started LinearDiscriminantAnalysiswith 5 features:totalScanTimeInSeconds',
#        'Started LinearDiscriminantAnalysiswith 5 features:trustLevel'],
#       dtype='object')
# Finished LinearDiscriminantAnalysiswith 5 features: after 0.09026622772216797 seconds
# Monetary Value Per Instance - Mean 0.16449953349953347
# Monetary Value Per Instance - Standard Deviation 0.009853188077668955
# Index(['Started LogisticRegressionwith 5 features:pricePerScannedLineItem',
#        'Started LogisticRegressionwith 5 features:scannedLineItems',
#        'Started LogisticRegressionwith 5 features:scansWithoutRegistration',
#        'Started LogisticRegressionwith 5 features:totalScanTimeInSeconds',
#        'Started LogisticRegressionwith 5 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionwith 5 features: after 0.2725679874420166 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started LogisticRegressionCVwith 5 features:pricePerScannedLineItem',
#        'Started LogisticRegressionCVwith 5 features:scannedLineItems',
#        'Started LogisticRegressionCVwith 5 features:scansWithoutRegistration',
#        'Started LogisticRegressionCVwith 5 features:totalScanTimeInSeconds',
#        'Started LogisticRegressionCVwith 5 features:trustLevel'],
#       dtype='object')
# Finished LogisticRegressionCVwith 5 features: after 9.428320169448853 seconds
# Monetary Value Per Instance - Mean 0.1669995334995335
# Monetary Value Per Instance - Standard Deviation 0.007472459287025263
#
# Index(['Started MultinomialNBwith 5 features:pricePerScannedLineItem',
#        'Started MultinomialNBwith 5 features:scannedLineItems',
#        'Started MultinomialNBwith 5 features:scansWithoutRegistration',
#        'Started MultinomialNBwith 5 features:totalScanTimeInSeconds',
#        'Started MultinomialNBwith 5 features:trustLevel'],
#       dtype='object')
# Finished MultinomialNBwith 5 features: after 0.06504130363464355 seconds
# Monetary Value Per Instance - Mean -1.4930098075098075
# Monetary Value Per Instance - Standard Deviation 0.19614168219999506
#
# Index(['Started NearestCentroidwith 5 features:pricePerScannedLineItem',
# ...
#        'Started ExtraTreesClassifierwith 14 features:scannedLineItems',
#        'Started ExtraTreesClassifierwith 14 features:scannedLineItemsPerSecond',
#        'Started ExtraTreesClassifierwith 14 features:scansWithoutRegistration',
#        'Started ExtraTreesClassifierwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started ExtraTreesClassifierwith 14 features:totalScanTimeInSeconds',
#        'Started ExtraTreesClassifierwith 14 features:trustLevel',
#        'Started ExtraTreesClassifierwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished ExtraTreesClassifierwith 14 features: after 0.17110753059387207 seconds
# Monetary Value Per Instance - Mean 0.1659995334995335
# Monetary Value Per Instance - Standard Deviation 0.007670509422151642
#
# Index(['Started RandomForestClassifierwith 14 features:grandTotal',
#        'Started RandomForestClassifierwith 14 features:lineItemVoids',
#        'Started RandomForestClassifierwith 14 features:lineItemVoidsPerPosition',
#        'Started RandomForestClassifierwith 14 features:lineItemVoidsPerSecond',
#        'Started RandomForestClassifierwith 14 features:pricePerScannedLineItem',
#        'Started RandomForestClassifierwith 14 features:quantityModifications',
#        'Started RandomForestClassifierwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started RandomForestClassifierwith 14 features:scannedLineItems',
#        'Started RandomForestClassifierwith 14 features:scannedLineItemsPerSecond',
#        'Started RandomForestClassifierwith 14 features:scansWithoutRegistration',
#        'Started RandomForestClassifierwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started RandomForestClassifierwith 14 features:totalScanTimeInSeconds',
#        'Started RandomForestClassifierwith 14 features:trustLevel',
#        'Started RandomForestClassifierwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished RandomForestClassifierwith 14 features: after 0.31330156326293945 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started BernoulliNBwith 14 features:grandTotal',
#        'Started BernoulliNBwith 14 features:lineItemVoids',
#        'Started BernoulliNBwith 14 features:lineItemVoidsPerPosition',
#        'Started BernoulliNBwith 14 features:lineItemVoidsPerSecond',
#        'Started BernoulliNBwith 14 features:pricePerScannedLineItem',
#        'Started BernoulliNBwith 14 features:quantityModifications',
#        'Started BernoulliNBwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started BernoulliNBwith 14 features:scannedLineItems',
#        'Started BernoulliNBwith 14 features:scannedLineItemsPerSecond',
#        'Started BernoulliNBwith 14 features:scansWithoutRegistration',
#        'Started BernoulliNBwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started BernoulliNBwith 14 features:totalScanTimeInSeconds',
#        'Started BernoulliNBwith 14 features:trustLevel',
#        'Started BernoulliNBwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished BernoulliNBwith 14 features: after 0.0498659610748291 seconds
# Monetary Value Per Instance - Mean -0.174502036002036
# Monetary Value Per Instance - Standard Deviation 0.00911037507771416
#
# Index(['Started GaussianNBwith 14 features:grandTotal',
#        'Started GaussianNBwith 14 features:lineItemVoids',
#        'Started GaussianNBwith 14 features:lineItemVoidsPerPosition',
#        'Started GaussianNBwith 14 features:lineItemVoidsPerSecond',
#        'Started GaussianNBwith 14 features:pricePerScannedLineItem',
#        'Started GaussianNBwith 14 features:quantityModifications',
#        'Started GaussianNBwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started GaussianNBwith 14 features:scannedLineItems',
#        'Started GaussianNBwith 14 features:scannedLineItemsPerSecond',
#        'Started GaussianNBwith 14 features:scansWithoutRegistration',
#        'Started GaussianNBwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started GaussianNBwith 14 features:totalScanTimeInSeconds',
#        'Started GaussianNBwith 14 features:trustLevel',
#        'Started GaussianNBwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished GaussianNBwith 14 features: after 0.05086541175842285 seconds
# Monetary Value Per Instance - Mean 0.1624985324985325
# Monetary Value Per Instance - Standard Deviation 0.010038317159755275
#
# Index(['Started LinearDiscriminantAnalysiswith 14 features:grandTotal',
#        'Started LinearDiscriminantAnalysiswith 14 features:lineItemVoids',
#        'Started LinearDiscriminantAnalysiswith 14 features:lineItemVoidsPerPosition',
#        'Started LinearDiscriminantAnalysiswith 14 features:lineItemVoidsPerSecond',
#        'Started LinearDiscriminantAnalysiswith 14 features:pricePerScannedLineItem',
#        'Started LinearDiscriminantAnalysiswith 14 features:quantityModifications',
#        'Started LinearDiscriminantAnalysiswith 14 features:quantityModificationsPerScannedLineItem',
#        'Started LinearDiscriminantAnalysiswith 14 features:scannedLineItems',
#        'Started LinearDiscriminantAnalysiswith 14 features:scannedLineItemsPerSecond',
#        'Started LinearDiscriminantAnalysiswith 14 features:scansWithoutRegistration',
#        'Started LinearDiscriminantAnalysiswith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started LinearDiscriminantAnalysiswith 14 features:totalScanTimeInSeconds',
#        'Started LinearDiscriminantAnalysiswith 14 features:trustLevel',
#        'Started LinearDiscriminantAnalysiswith 14 features:valuePerSecond'],
#       dtype='object')
# Finished LinearDiscriminantAnalysiswith 14 features: after 0.1496281623840332 seconds
# Monetary Value Per Instance - Mean 0.1619995334995335
# Monetary Value Per Instance - Standard Deviation 0.011217530155590632
#
# Index(['Started LogisticRegressionwith 14 features:grandTotal',
#        'Started LogisticRegressionwith 14 features:lineItemVoids',
#        'Started LogisticRegressionwith 14 features:lineItemVoidsPerPosition',
#        'Started LogisticRegressionwith 14 features:lineItemVoidsPerSecond',
#        'Started LogisticRegressionwith 14 features:pricePerScannedLineItem',
#        'Started LogisticRegressionwith 14 features:quantityModifications',
#        'Started LogisticRegressionwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started LogisticRegressionwith 14 features:scannedLineItems',
#        'Started LogisticRegressionwith 14 features:scannedLineItemsPerSecond',
#        'Started LogisticRegressionwith 14 features:scansWithoutRegistration',
#        'Started LogisticRegressionwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started LogisticRegressionwith 14 features:totalScanTimeInSeconds',
#        'Started LogisticRegressionwith 14 features:trustLevel',
#        'Started LogisticRegressionwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished LogisticRegressionwith 14 features: after 0.45376086235046387 seconds
# Monetary Value Per Instance - Mean 0.1634995334995335
# Monetary Value Per Instance - Standard Deviation 0.00975112210430085
#
# Index(['Started LogisticRegressionCVwith 14 features:grandTotal',
#        'Started LogisticRegressionCVwith 14 features:lineItemVoids',
#        'Started LogisticRegressionCVwith 14 features:lineItemVoidsPerPosition',
#        'Started LogisticRegressionCVwith 14 features:lineItemVoidsPerSecond',
#        'Started LogisticRegressionCVwith 14 features:pricePerScannedLineItem',
#        'Started LogisticRegressionCVwith 14 features:quantityModifications',
#        'Started LogisticRegressionCVwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started LogisticRegressionCVwith 14 features:scannedLineItems',
#        'Started LogisticRegressionCVwith 14 features:scannedLineItemsPerSecond',
#        'Started LogisticRegressionCVwith 14 features:scansWithoutRegistration',
#        'Started LogisticRegressionCVwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started LogisticRegressionCVwith 14 features:totalScanTimeInSeconds',
#        'Started LogisticRegressionCVwith 14 features:trustLevel',
#        'Started LogisticRegressionCVwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished LogisticRegressionCVwith 14 features: after 51.87423062324524 seconds
# Monetary Value Per Instance - Mean 0.16449953349953347
# Monetary Value Per Instance - Standard Deviation 0.009853188077668955
#
# Index(['Started MultinomialNBwith 14 features:grandTotal',
#        'Started MultinomialNBwith 14 features:lineItemVoids',
#        'Started MultinomialNBwith 14 features:lineItemVoidsPerPosition',
#        'Started MultinomialNBwith 14 features:lineItemVoidsPerSecond',
#        'Started MultinomialNBwith 14 features:pricePerScannedLineItem',
#        'Started MultinomialNBwith 14 features:quantityModifications',
#        'Started MultinomialNBwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started MultinomialNBwith 14 features:scannedLineItems',
#        'Started MultinomialNBwith 14 features:scannedLineItemsPerSecond',
#        'Started MultinomialNBwith 14 features:scansWithoutRegistration',
#        'Started MultinomialNBwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started MultinomialNBwith 14 features:totalScanTimeInSeconds',
#        'Started MultinomialNBwith 14 features:trustLevel',
#        'Started MultinomialNBwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished MultinomialNBwith 14 features: after 0.039896488189697266 seconds
# Monetary Value Per Instance - Mean -6.135513248013249
# Monetary Value Per Instance - Standard Deviation 0.27480460114762617
#
# Index(['Started NearestCentroidwith 14 features:grandTotal',
#        'Started NearestCentroidwith 14 features:lineItemVoids',
#        'Started NearestCentroidwith 14 features:lineItemVoidsPerPosition',
#        'Started NearestCentroidwith 14 features:lineItemVoidsPerSecond',
#        'Started NearestCentroidwith 14 features:pricePerScannedLineItem',
#        'Started NearestCentroidwith 14 features:quantityModifications',
#        'Started NearestCentroidwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started NearestCentroidwith 14 features:scannedLineItems',
#        'Started NearestCentroidwith 14 features:scannedLineItemsPerSecond',
#        'Started NearestCentroidwith 14 features:scansWithoutRegistration',
#        'Started NearestCentroidwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started NearestCentroidwith 14 features:totalScanTimeInSeconds',
#        'Started NearestCentroidwith 14 features:trustLevel',
#        'Started NearestCentroidwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished NearestCentroidwith 14 features: after 0.03889632225036621 seconds
# Monetary Value Per Instance - Mean -10.652093111093112
# Monetary Value Per Instance - Standard Deviation 0.3533148021642347
#
# Index(['Started Perceptronwith 14 features:grandTotal',
#        'Started Perceptronwith 14 features:lineItemVoids',
#        'Started Perceptronwith 14 features:lineItemVoidsPerPosition',
#        'Started Perceptronwith 14 features:lineItemVoidsPerSecond',
#        'Started Perceptronwith 14 features:pricePerScannedLineItem',
#        'Started Perceptronwith 14 features:quantityModifications',
#        'Started Perceptronwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started Perceptronwith 14 features:scannedLineItems',
#        'Started Perceptronwith 14 features:scannedLineItemsPerSecond',
#        'Started Perceptronwith 14 features:scansWithoutRegistration',
#        'Started Perceptronwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started Perceptronwith 14 features:totalScanTimeInSeconds',
#        'Started Perceptronwith 14 features:trustLevel',
#        'Started Perceptronwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished Perceptronwith 14 features: after 0.05884218215942383 seconds
# Monetary Value Per Instance - Mean -0.4660160550160549
# Monetary Value Per Instance - Standard Deviation 0.31101717913574367
#
# Index(['Started QuadraticDiscriminantAnalysiswith 14 features:grandTotal',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:lineItemVoids',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:lineItemVoidsPerPosition',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:lineItemVoidsPerSecond',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:pricePerScannedLineItem',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:quantityModifications',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:quantityModificationsPerScannedLineItem',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:scannedLineItems',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:scannedLineItemsPerSecond',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:scansWithoutRegistration',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:totalScanTimeInSeconds',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:trustLevel',
#        'Started QuadraticDiscriminantAnalysiswith 14 features:valuePerSecond'],
#       dtype='object')
# Finished QuadraticDiscriminantAnalysiswith 14 features: after 0.054853200912475586 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Monetary Value Per Instance - Mean 0.13149953149953147
# Monetary Value Per Instance - Standard Deviation 0.10074757119801218
#
# Index(['Started SVCwith 14 features:grandTotal',
#        'Started SVCwith 14 features:lineItemVoids',
#        'Started SVCwith 14 features:lineItemVoidsPerPosition',
#        'Started SVCwith 14 features:lineItemVoidsPerSecond',
#        'Started SVCwith 14 features:pricePerScannedLineItem',
#        'Started SVCwith 14 features:quantityModifications',
#        'Started SVCwith 14 features:quantityModificationsPerScannedLineItem',
#        'Started SVCwith 14 features:scannedLineItems',
#        'Started SVCwith 14 features:scannedLineItemsPerSecond',
#        'Started SVCwith 14 features:scansWithoutRegistration',
#        'Started SVCwith 14 features:scansWithoutRegistrationPerScannedLineItem',
#        'Started SVCwith 14 features:totalScanTimeInSeconds',
#        'Started SVCwith 14 features:trustLevel',
#        'Started SVCwith 14 features:valuePerSecond'],
#       dtype='object')
# Finished SVCwith 14 features: after 103.8913300037384 seconds
# Monetary Value Per Instance - Mean -0.1694995334995335
# Monetary Value Per Instance - Standard Deviation 0.001445676415586323
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-e6c1ceed42cd> in <module>
#      10   t = time.time()
#      11
# ---> 12   best_features = SelectKBest(f_classif, k=feature_count).fit(X,Y)
#      13   best_feature_list = X.columns[best_features.get_support()]
#      14
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in fit(self, X, y)
#     346                             % (self.score_func, type(self.score_func)))
#     347
# --> 348         self._check_params(X, y)
#     349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _check_params(self, X, y)
#     512             raise ValueError("k should be >=0, <= n_features = %d; got %r. "
#     513                              "Use k='all' to return all features."
# --> 514                              % (X.shape[1], self.k))
#     515
#     516     def _get_support_mask(self):
#
# ValueError: k should be >=0, <= n_features = 14; got 15. Use k='all' to return all features.

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                              Model Feature Count  \
# 87                             SVC             4
# 65                             SVC             3
# 47                   SGDClassifier             3
# 121         RandomForestClassifier             6
# 230           ExtraTreesClassifier            11
# 99          RandomForestClassifier             5
# 252           ExtraTreesClassifier            12
# 253         RandomForestClassifier            12
# 46            KNeighborsClassifier             3
# 76            ExtraTreesClassifier             4
# 69                   SGDClassifier             4
# 68            KNeighborsClassifier             4
# 123                     GaussianNB             6
# 275         RandomForestClassifier            13
# 57                      GaussianNB             3
# 55          RandomForestClassifier             3
# 77          RandomForestClassifier             4
# 274           ExtraTreesClassifier            13
# 165         RandomForestClassifier             8
# 164           ExtraTreesClassifier             8
# 192           LogisticRegressionCV             9
# 170           LogisticRegressionCV             8
# 258           LogisticRegressionCV            12
# 168     LinearDiscriminantAnalysis             8
# 280           LogisticRegressionCV            13
# 104           LogisticRegressionCV             5
# 236           LogisticRegressionCV            11
# 214           LogisticRegressionCV            10
# 148           LogisticRegressionCV             7
# 143         RandomForestClassifier             7
# ..                             ...           ...
# 42   QuadraticDiscriminantAnalysis             2
# 86   QuadraticDiscriminantAnalysis             4
# 130  QuadraticDiscriminantAnalysis             6
# 240  QuadraticDiscriminantAnalysis            11
# 284  QuadraticDiscriminantAnalysis            13
# 20   QuadraticDiscriminantAnalysis             1
# 262  QuadraticDiscriminantAnalysis            12
# 179                  SGDClassifier             9
# 157                  SGDClassifier             8
# 113                  SGDClassifier             6
# 226    PassiveAggressiveClassifier            11
# 193                  MultinomialNB             9
# 215                  MultinomialNB            10
# 281                  MultinomialNB            13
# 237                  MultinomialNB            11
# 259                  MultinomialNB            12
# 303                  MultinomialNB            14
# 62                 NearestCentroid             3
# 40                 NearestCentroid             2
# 84                 NearestCentroid             4
# 172                NearestCentroid             8
# 150                NearestCentroid             7
# 128                NearestCentroid             6
# 106                NearestCentroid             5
# 304                NearestCentroid            14
# 282                NearestCentroid            13
# 238                NearestCentroid            11
# 260                NearestCentroid            12
# 194                NearestCentroid             9
# 216                NearestCentroid            10
#
#                                               Features  \
# 87   Index(['pricePerScannedLineItem', 'scannedLine...
# 65   Index(['scannedLineItems', 'scansWithoutRegist...
# 47   Index(['scannedLineItems', 'scansWithoutRegist...
# 121  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 230  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 99   Index(['pricePerScannedLineItem', 'scannedLine...
# 252  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 253  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 46   Index(['scannedLineItems', 'scansWithoutRegist...
# 76   Index(['pricePerScannedLineItem', 'scannedLine...
# 69   Index(['pricePerScannedLineItem', 'scannedLine...
# 68   Index(['pricePerScannedLineItem', 'scannedLine...
# 123  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 275  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 57   Index(['scannedLineItems', 'scansWithoutRegist...
# 55   Index(['scannedLineItems', 'scansWithoutRegist...
# 77   Index(['pricePerScannedLineItem', 'scannedLine...
# 274  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 165  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 164  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 192  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 170  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 258  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 168  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 280  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 104  Index(['pricePerScannedLineItem', 'scannedLine...
# 236  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 214  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 148  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 143  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# ..                                                 ...
# 42   Index(['scannedLineItems', 'trustLevel'], dtyp...
# 86   Index(['pricePerScannedLineItem', 'scannedLine...
# 130  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 240  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 284  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 20               Index(['trustLevel'], dtype='object')
# 262  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 179  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 157  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 113  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 226  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 193  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 215  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 281  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 237  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 259  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 303  Index(['grandTotal', 'lineItemVoids', 'lineIte...
# 62   Index(['scannedLineItems', 'scansWithoutRegist...
# 40   Index(['scannedLineItems', 'trustLevel'], dtyp...
# 84   Index(['pricePerScannedLineItem', 'scannedLine...
# 172  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 150  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 128  Index(['lineItemVoidsPerPosition', 'pricePerSc...
# 106  Index(['pricePerScannedLineItem', 'scannedLine...
# 304  Index(['grandTotal', 'lineItemVoids', 'lineIte...
# 282  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 238  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 260  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 194  Index(['grandTotal', 'lineItemVoidsPerPosition...
# 216  Index(['grandTotal', 'lineItemVoidsPerPosition...
#
#      Monetary Value Per Instance - Mean  \
# 87                             0.169500
# 65                             0.169500
# 47                             0.169500
# 121                            0.168500
# 230                            0.168500
# 99                             0.168500
# 252                            0.168500
# 253                            0.168500
# 46                             0.168500
# 76                             0.168500
# 69                             0.168500
# 68                             0.168500
# 123                            0.168500
# 275                            0.168500
# 57                             0.168500
# 55                             0.168500
# 77                             0.168500
# 274                            0.168500
# 165                            0.168500
# 164                            0.167500
# 192                            0.167000
# 170                            0.167000
# 258                            0.167000
# 168                            0.167000
# 280                            0.167000
# 104                            0.167000
# 236                            0.167000
# 214                            0.167000
# 148                            0.167000
# 143                            0.166000
# ..                                  ...
# 42                            -2.248000
# 86                            -2.248000
# 130                           -2.248000
# 240                           -2.251001
# 284                           -2.252000
# 20                            -2.253000
# 262                           -2.253000
# 179                           -2.311504
# 157                           -2.449845
# 113                           -2.589006
# 226                           -2.933500
# 193                           -6.035517
# 215                           -6.112014
# 281                           -6.118519
# 237                           -6.119512
# 259                           -6.134512
# 303                           -6.135513
# 62                            -7.220487
# 40                            -7.482987
# 84                            -7.940465
# 172                          -10.649593
# 150                          -10.649593
# 128                          -10.649593
# 106                          -10.649593
# 304                          -10.652093
# 282                          -10.652093
# 238                          -10.652093
# 260                          -10.652093
# 194                          -10.652093
# 216                          -10.652093
#
#      Monetary Value Per Instance - Standard Deviation
# 87                                           0.001446
# 65                                           0.001446
# 47                                           0.001446
# 121                                          0.003176
# 230                                          0.003176
# 99                                           0.003176
# 252                                          0.003176
# 253                                          0.003176
# 46                                           0.003176
# 76                                           0.003176
# 69                                           0.003176
# 68                                           0.003176
# 123                                          0.003176
# 275                                          0.003176
# 57                                           0.003176
# 55                                           0.003176
# 77                                           0.003176
# 274                                          0.003176
# 165                                          0.003176
# 164                                          0.004011
# 192                                          0.007472
# 170                                          0.007472
# 258                                          0.007472
# 168                                          0.007472
# 280                                          0.007472
# 104                                          0.007472
# 236                                          0.007472
# 214                                          0.007472
# 148                                          0.007472
# 143                                          0.007671
# ..                                                ...
# 42                                           7.244004
# 86                                           7.244004
# 130                                          7.244004
# 240                                          7.243007
# 284                                          7.242672
# 20                                           7.242341
# 262                                          7.242342
# 179                                          6.081570
# 157                                          6.437966
# 113                                          6.964254
# 226                                          5.535888
# 193                                          0.256388
# 215                                          0.276196
# 281                                          0.282643
# 237                                          0.288149
# 259                                          0.279320
# 303                                          0.274805
# 62                                           0.344620
# 40                                           0.381828
# 84                                           0.418751
# 172                                          0.350711
# 150                                          0.350711
# 128                                          0.350711
# 106                                          0.350711
# 304                                          0.353315
# 282                                          0.353315
# 238                                          0.353315
# 260                                          0.353315
# 194                                          0.353315
# 216                                          0.353315
#
# [308 rows x 5 columns]

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

best_features = SelectKBest(f_classif, k=1).fit(X,Y)
best_feature_list = X.columns[best_features.get_support()]

X = X[best_feature_list]

X.columns
# Out:
# Index(['trustLevel'], dtype='object')

# %%
import time

result_table = pd.DataFrame(columns=["Model", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation"])

for model in model_factory:
 
 t = time.time()
# print("Started " + model.__class__.__name__)

 model.seed = 42

 scores = cross_val_score(model, X, Y, cv=skf, scoring=my_custom_score)
 model_name = model.__class__.__name__
 score_mean = scores.mean()
 score_std = scores.std()

# print("Finished " + model.__class__.__name__ + " after " + str(time.time() - t) + " seconds")
# print("Monetary Value Per Instance - Mean " + str(score_mean))
# print("Monetary Value Per Instance - Standard Deviation " + str(score_std))  
# print("")  
    
 result_table = result_table.append({
     "Model": model_name,
     "Monetary Value Per Instance - Mean":  score_mean,
     "Monetary Value Per Instance - Standard Deviation": score_std
      }, ignore_index=True)

       
       
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:720: RuntimeWarning: invalid value encountered in add
#   return (-0.5 * (norm2 + u) + np.log(self.priors_))
#                             Model  Monetary Value Per Instance - Mean  \
# 0             ExtraTreeClassifier                            0.141000
# 9               BaggingClassifier                            0.141000
# 19                     Perceptron                            0.141000
# 16           LogisticRegressionCV                            0.141000
# 15             LogisticRegression                            0.141000
# 14     LinearDiscriminantAnalysis                            0.141000
# 13                     GaussianNB                            0.141000
# 11         RandomForestClassifier                            0.141000
# 1          DecisionTreeClassifier                            0.141000
# 10           ExtraTreesClassifier                            0.141000
# 8      GradientBoostingClassifier                            0.141000
# 7              AdaBoostClassifier                            0.141000
# 6     PassiveAggressiveClassifier                            0.141000
# 3                   SGDClassifier                            0.141000
# 2            KNeighborsClassifier                            0.141000
# 18                NearestCentroid                            0.117005
# 12                    BernoulliNB                           -0.164500
# 5                 RidgeClassifier                           -0.164500
# 4               RidgeClassifierCV                           -0.164500
# 17                  MultinomialNB                           -0.164500
# 20  QuadraticDiscriminantAnalysis                           -2.270500
#
#     Monetary Value Per Instance - Standard Deviation
# 0                                           0.025474
# 9                                           0.025474
# 19                                          0.025474
# 16                                          0.025474
# 15                                          0.025474
# 14                                          0.025474
# 13                                          0.025474
# 11                                          0.025474
# 1                                           0.025474
# 10                                          0.025474
# 8                                           0.025474
# 7                                           0.025474
# 6                                           0.025474
# 3                                           0.025474
# 2                                           0.025474
# 18                                          0.030603
# 12                                          0.001447
# 5                                           0.001447
# 4                                           0.001447
# 17                                          0.001447
# 20                                          7.246535
