# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
train=pd.read_csv('train.csv',sep='|')
test=pd.read_csv('test.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
# for training set

#train['totalScanTimeInMinutes'] = train['totalScanTimeInSeconds'] / 60.0
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
#rain['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
#train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
#train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
#train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
#train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
#train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']


# for test set

#train['totalScanTimeInMinutes'] = train['totalScanTimeInSeconds'] / 60.0
test['scannedLineItems'] = test['scannedLineItemsPerSecond'] * test['totalScanTimeInSeconds']
test['pricePerScannedLineItem'] = test['grandTotal'] / test['scannedLineItems']
test['scansWithoutRegistrationPerScannedLineItem'] = test['scansWithoutRegistration'] / test['scannedLineItems']
test['quantityModificationsPerScannedLineItem'] = test['quantityModifications'] / test['scannedLineItems']
test['lineItemVoidsPerSecond'] = test['lineItemVoids'] / test['totalScanTimeInSeconds']
#rain['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
#train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
#train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
#train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
#train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
#train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %% [markdown]
# # Larger training set due to rules found at Decision Tree Analysis

# %%
additional_no_frauds = test[test["trustLevel"] > 2.5]
additional_no_frauds = additional_no_frauds.assign(fraud = 0)

additional_frauds = test[(test["trustLevel"] < 1.5) &  (test["scannedLineItems"] > 20.5) & (test["valuePerSecond"] <= 0.118) & (test["scansWithoutRegistrationPerScannedLineItem"] > 0.168)]
additional_frauds = additional_frauds.assign(fraud = 1)


train = pd.concat([train, additional_no_frauds], ignore_index=True)
train = pd.concat([train, additional_frauds], ignore_index=True)

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    334270
# 1     12217
# Name: fraud, dtype: int64
# 0    0.96474
# 1    0.03526
# Name: fraud, dtype: float64

# %%
from sklearn.tree import ExtraTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm.classes import OneClassSVM
from sklearn.neural_network.multilayer_perceptron import MLPClassifier
from sklearn.neighbors.classification import RadiusNeighborsClassifier
from sklearn.neighbors.classification import KNeighborsClassifier
from sklearn.multioutput import ClassifierChain
from sklearn.multioutput import MultiOutputClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model.stochastic_gradient import SGDClassifier
from sklearn.linear_model.ridge import RidgeClassifierCV
from sklearn.linear_model.ridge import RidgeClassifier
from sklearn.linear_model.passive_aggressive import PassiveAggressiveClassifier
from sklearn.gaussian_process.gpc import GaussianProcessClassifier
from sklearn.ensemble.voting_classifier import VotingClassifier
from sklearn.ensemble.weight_boosting import AdaBoostClassifier
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
from sklearn.ensemble.bagging import BaggingClassifier
from sklearn.ensemble.forest import ExtraTreesClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import GaussianNB
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.svm import SVC
# from sklearn.mixture import DPGMM
#from sklearn.mixture import GMM
#from sklearn.mixture import GaussianMixture
#from sklearn.mixture import VBGMM



model_factory = [
# RandomForestRegressor(),
# XGBRegressor(nthread=1),
 #MLPRegressor(),
# Ridge(),
# BayesianRidge(),
# ExtraTreesRegressor(),
# ElasticNet(),
# KNeighborsRegressor(),
# GradientBoostingRegressor()
  ExtraTreeClassifier(),
    DecisionTreeClassifier(),
 #   OneClassSVM(),  # doesn't work instantly
    
                  # MLPClassifier(),# takes very long for a larger training set
    
 #   RadiusNeighborsClassifier(), # doesn't work instantly
    KNeighborsClassifier(),
#    ClassifierChain(),     # ensemble method
#    MultiOutputClassifier(), # ensemble method
#    OutputCodeClassifier(), # ensemble method
#    OneVsOneClassifier(), # ensemble method
#    OneVsRestClassifier(), # ensemble method
    SGDClassifier(),
    RidgeClassifierCV(),
    RidgeClassifier(),
    PassiveAggressiveClassifier(),
    
                   # GaussianProcessClassifier(),  # takes very long for a larger training set
    
#    VotingClassifier(), # ensemble method
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    BaggingClassifier(),
    ExtraTreesClassifier(),
    RandomForestClassifier(),
    BernoulliNB(),
  #  CalibratedClassifierCV(), # doesn't work instantly
    GaussianNB(), # causing some problems
 #   LabelPropagation(), # doesn't work instantly
 #   LabelSpreading(),  # doesn't work instantly
    LinearDiscriminantAnalysis(), # causing some problems
 #   LinearSVC(max_iter = 100000), # causing some problems
    LogisticRegression(max_iter = 10000),
    LogisticRegressionCV(max_iter = 10000),
    MultinomialNB(),
    NearestCentroid(),
  #  NuSVC(),   # doesn't work instantly
    Perceptron(),
    QuadraticDiscriminantAnalysis(),
    # SVC(),
#    DPGMM(),
#    GMM(),
#    GaussianMixture(),
#    VBGMM()
]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer

def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)
loo = LeaveOneOut()

# %% [markdown]
# # Take a smaller sample for quicker training

# %%
train = train.sample(50000)

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    48281
# 1     1719
# Name: fraud, dtype: int64
# 0    0.96562
# 1    0.03438
# Name: fraud, dtype: float64

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

result_table = pd.DataFrame(columns=["Model", "Feature Count", "Features", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


for feature_count in range(1,len(list(X))+1):

 for model in model_factory:
 
  t = time.time()
    
  best_features = SelectKBest(f_classif, k=feature_count).fit(X,Y)
  best_feature_list = X.columns[best_features.get_support()]

  X_selected_features = X[best_feature_list]
    
#  print("Started " + model.__class__.__name__ + "with " + str(feature_count) + " features:" + best_feature_list)

  model.seed = 42

  scores = cross_val_score(model, X_selected_features, Y, cv=skf, scoring=my_custom_score)
  model_name = model.__class__.__name__
  score_mean = scores.mean()
  score_std = scores.std()

#  print("Finished " + model.__class__.__name__ + " with " + str(feature_count) + " features:" + " after " + str(time.time() - t) + " seconds")
#  print("Monetary Value Per Instance - Mean " + str(score_mean))
#  print("Monetary Value Per Instance - Standard Deviation " + str(score_std))  
#  print("")  
    
  result_table = result_table.append({
     "Model": model_name,
     "Feature Count": feature_count,
     "Features": best_feature_list.values,
     "Monetary Value Per Instance - Mean":  score_mean,
     "Monetary Value Per Instance - Standard Deviation": score_std,
     "Raw Model": model
      }, ignore_index=True)
 
 print("Iteration " + str(feature_count) + " finished") 
    
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Iteration: 1 finished
# Iteration: 2 finished
# Iteration: 3 finished
# Iteration: 4 finished
# Iteration: 5 finished
# Iteration: 6 finished
# Iteration: 7 finished
# Iteration: 8 finished
# Iteration: 9 finished
# Iteration: 10 finished
# Iteration: 11 finished
# Iteration: 12 finished
# Iteration: 13 finished
# Iteration: 14 finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b2c5ab8a0906> in <module>
#      13   t = time.time()
#      14
# ---> 15   best_features = SelectKBest(f_classif, k=feature_count).fit(X,Y)
#      16   best_feature_list = X.columns[best_features.get_support()]
#      17
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in fit(self, X, y)
#     346                             % (self.score_func, type(self.score_func)))
#     347
# --> 348         self._check_params(X, y)
#     349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _check_params(self, X, y)
#     512             raise ValueError("k should be >=0, <= n_features = %d; got %r. "
#     513                              "Use k='all' to return all features."
# --> 514                              % (X.shape[1], self.k))
#     515
#     516     def _get_support_mask(self):
#
# ValueError: k should be >=0, <= n_features = 14; got 15. Use k='all' to return all features.

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                              Model Feature Count                                           Features  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 219              BaggingClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.169500                                          0.003822  BaggingClassifier(base_estimator=None, bootstr...
# 263         RandomForestClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.169500                                          0.003822  RandomForestClassifier(bootstrap=True, class_w...
# 240              BaggingClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.169300                                          0.003738  BaggingClassifier(base_estimator=None, bootstr...
# 200         RandomForestClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.169100                                          0.003640  RandomForestClassifier(bootstrap=True, class_w...
# 156              BaggingClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.169100                                          0.003640  BaggingClassifier(base_estimator=None, bootstr...
# 209  QuadraticDiscriminantAnalysis            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.169000                                          0.002315  QuadraticDiscriminantAnalysis(priors=None, reg...
# 137         RandomForestClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.169000                                          0.004509  RandomForestClassifier(bootstrap=True, class_w...
# 32          RandomForestClassifier             2                     [scannedLineItems, trustLevel]                            0.169000                                          0.004509  RandomForestClassifier(bootstrap=True, class_w...
# 31            ExtraTreesClassifier             2                     [scannedLineItems, trustLevel]                            0.169000                                          0.004509  ExtraTreesClassifier(bootstrap=False, class_we...
# 29      GradientBoostingClassifier             2                     [scannedLineItems, trustLevel]                            0.169000                                          0.004509  GradientBoostingClassifier(criterion='friedman...
# 22          DecisionTreeClassifier             2                     [scannedLineItems, trustLevel]                            0.169000                                          0.004509  DecisionTreeClassifier(class_weight=None, crit...
# 242         RandomForestClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168900                                          0.003640  RandomForestClassifier(bootstrap=True, class_w...
# 52            ExtraTreesClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.168900                                          0.004292  ExtraTreesClassifier(bootstrap=False, class_we...
# 178           ExtraTreesClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168800                                          0.003939  ExtraTreesClassifier(bootstrap=False, class_we...
# 199           ExtraTreesClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168800                                          0.003677  ExtraTreesClassifier(bootstrap=False, class_we...
# 284         RandomForestClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.168700                                          0.003517  RandomForestClassifier(bootstrap=True, class_w...
# 253         DecisionTreeClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168600                                          0.003554  DecisionTreeClassifier(class_weight=None, crit...
# 176     GradientBoostingClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168600                                          0.003554  GradientBoostingClassifier(criterion='friedman...
# 281     GradientBoostingClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.168600                                          0.003554  GradientBoostingClassifier(criterion='friedman...
# 261              BaggingClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168600                                          0.003550  BaggingClassifier(base_estimator=None, bootstr...
# 241           ExtraTreesClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168600                                          0.003821  ExtraTreesClassifier(bootstrap=False, class_we...
# 211         DecisionTreeClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168600                                          0.004195  DecisionTreeClassifier(class_weight=None, crit...
# 177              BaggingClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168600                                          0.004309  BaggingClassifier(base_estimator=None, bootstr...
# 158         RandomForestClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168600                                          0.004309  RandomForestClassifier(bootstrap=True, class_w...
# 116         RandomForestClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168600                                          0.004309  RandomForestClassifier(bootstrap=True, class_w...
# 74          RandomForestClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.168600                                          0.004791  RandomForestClassifier(bootstrap=True, class_w...
# 21             ExtraTreeClassifier             2                     [scannedLineItems, trustLevel]                            0.168500                                          0.004425  ExtraTreeClassifier(class_weight=None, criteri...
# 30               BaggingClassifier             2                     [scannedLineItems, trustLevel]                            0.168500                                          0.004425  BaggingClassifier(base_estimator=None, bootstr...
# 28              AdaBoostClassifier             2                     [scannedLineItems, trustLevel]                            0.168500                                          0.005527  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 53          RandomForestClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.168400                                          0.004191  RandomForestClassifier(bootstrap=True, class_w...
# 179         RandomForestClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168400                                          0.004191  RandomForestClassifier(bootstrap=True, class_w...
# 221         RandomForestClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168400                                          0.004191  RandomForestClassifier(bootstrap=True, class_w...
# 95          RandomForestClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168400                                          0.004686  RandomForestClassifier(bootstrap=True, class_w...
# 73            ExtraTreesClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.168300                                          0.003841  ExtraTreesClassifier(bootstrap=False, class_we...
# 64          DecisionTreeClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.168200                                          0.004061  DecisionTreeClassifier(class_weight=None, crit...
# 274         DecisionTreeClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.168100                                          0.004064  DecisionTreeClassifier(class_weight=None, crit...
# 190         DecisionTreeClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168100                                          0.003667  DecisionTreeClassifier(class_weight=None, crit...
# 155     GradientBoostingClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 197     GradientBoostingClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 218     GradientBoostingClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 260     GradientBoostingClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 50      GradientBoostingClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 239     GradientBoostingClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168100                                          0.004178  GradientBoostingClassifier(criterion='friedman...
# 198              BaggingClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.168100                                          0.005328  BaggingClassifier(base_estimator=None, bootstr...
# 217             AdaBoostClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.168100                                          0.005328  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 93               BaggingClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168100                                          0.005328  BaggingClassifier(base_estimator=None, bootstr...
# 135              BaggingClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168100                                          0.005328  BaggingClassifier(base_estimator=None, bootstr...
# 114              BaggingClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.168000                                          0.004016  BaggingClassifier(base_estimator=None, bootstr...
# 107           KNeighborsClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167900                                          0.003207  KNeighborsClassifier(algorithm='auto', leaf_si...
# 86            KNeighborsClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167900                                          0.003207  KNeighborsClassifier(algorithm='auto', leaf_si...
# 169         DecisionTreeClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.167900                                          0.003909  DecisionTreeClassifier(class_weight=None, crit...
# 94            ExtraTreesClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167900                                          0.004031  ExtraTreesClassifier(bootstrap=False, class_we...
# 51               BaggingClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.167900                                          0.004606  BaggingClassifier(base_estimator=None, bootstr...
# 70              AdaBoostClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.167800                                          0.006635  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 49              AdaBoostClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.167800                                          0.006635  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 91              AdaBoostClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167800                                          0.006635  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 148         DecisionTreeClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167700                                          0.003843  DecisionTreeClassifier(class_weight=None, crit...
# 85          DecisionTreeClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167700                                          0.003869  DecisionTreeClassifier(class_weight=None, crit...
# 71      GradientBoostingClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.167700                                          0.005090  GradientBoostingClassifier(criterion='friedman...
# 72               BaggingClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.167700                                          0.005090  BaggingClassifier(base_estimator=None, bootstr...
# 232         DecisionTreeClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.167600                                          0.003440  DecisionTreeClassifier(class_weight=None, crit...
# 157           ExtraTreesClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167600                                          0.004215  ExtraTreesClassifier(bootstrap=False, class_we...
# 196             AdaBoostClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.167600                                          0.005174  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 238             AdaBoostClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.167600                                          0.005174  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 259             AdaBoostClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.167600                                          0.005174  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 134     GradientBoostingClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167600                                          0.005174  GradientBoostingClassifier(criterion='friedman...
# 220           ExtraTreesClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.167500                                          0.003262  ExtraTreesClassifier(bootstrap=False, class_we...
# 65            KNeighborsClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.167400                                          0.003230  KNeighborsClassifier(algorithm='auto', leaf_si...
# 262           ExtraTreesClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.167400                                          0.003521  ExtraTreesClassifier(bootstrap=False, class_we...
# 113     GradientBoostingClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167400                                          0.005037  GradientBoostingClassifier(criterion='friedman...
# 92      GradientBoostingClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167400                                          0.005037  GradientBoostingClassifier(criterion='friedman...
# 282              BaggingClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.167300                                          0.004495  BaggingClassifier(base_estimator=None, bootstr...
# 280             AdaBoostClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.167300                                          0.005305  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 106         DecisionTreeClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167200                                          0.003457  DecisionTreeClassifier(class_weight=None, crit...
# 127         DecisionTreeClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167200                                          0.003595  DecisionTreeClassifier(class_weight=None, crit...
# 283           ExtraTreesClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.167100                                          0.003112  ExtraTreesClassifier(bootstrap=False, class_we...
# 136           ExtraTreesClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.167100                                          0.004541  ExtraTreesClassifier(bootstrap=False, class_we...
# 188  QuadraticDiscriminantAnalysis             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.167000                                          0.004396  QuadraticDiscriminantAnalysis(priors=None, reg...
# 230  QuadraticDiscriminantAnalysis            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.166900                                          0.002833  QuadraticDiscriminantAnalysis(priors=None, reg...
# 55                      GaussianNB             3  [scannedLineItems, scansWithoutRegistration, t...                            0.166800                                          0.003704       GaussianNB(priors=None, var_smoothing=1e-09)
# 43          DecisionTreeClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.166800                                          0.005632  DecisionTreeClassifier(class_weight=None, crit...
# 175             AdaBoostClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.166800                                          0.006455  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 133             AdaBoostClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166800                                          0.006455  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 154             AdaBoostClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166800                                          0.006455  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 112             AdaBoostClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166800                                          0.006683  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 115           ExtraTreesClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166700                                          0.004375  ExtraTreesClassifier(bootstrap=False, class_we...
# 103                     Perceptron             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166500                                          0.003607  Perceptron(alpha=0.0001, class_weight=None, ea...
# 167  QuadraticDiscriminantAnalysis             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.166500                                          0.004071  QuadraticDiscriminantAnalysis(priors=None, reg...
# 34                      GaussianNB             2                     [scannedLineItems, trustLevel]                            0.166500                                          0.005155       GaussianNB(priors=None, var_smoothing=1e-09)
# 41   QuadraticDiscriminantAnalysis             2                     [scannedLineItems, trustLevel]                            0.166500                                          0.005155  QuadraticDiscriminantAnalysis(priors=None, reg...
# 42             ExtraTreeClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.166400                                          0.004266  ExtraTreeClassifier(class_weight=None, criteri...
# 82                      Perceptron             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.166200                                          0.003841  Perceptron(alpha=0.0001, class_weight=None, ea...
# 293  QuadraticDiscriminantAnalysis            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.166200                                          0.003015  QuadraticDiscriminantAnalysis(priors=None, reg...
# 202                     GaussianNB            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.166000                                          0.004166       GaussianNB(priors=None, var_smoothing=1e-09)
# 76                      GaussianNB             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.166000                                          0.004281       GaussianNB(priors=None, var_smoothing=1e-09)
# 62   QuadraticDiscriminantAnalysis             3  [scannedLineItems, scansWithoutRegistration, t...                            0.166000                                          0.004830  QuadraticDiscriminantAnalysis(priors=None, reg...
# 226           LogisticRegressionCV            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.166000                                          0.006346  LogisticRegressionCV(Cs=10, class_weight=None,...
# 84             ExtraTreeClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165800                                          0.006058  ExtraTreeClassifier(class_weight=None, criteri...
# 272  QuadraticDiscriminantAnalysis            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.165700                                          0.003089  QuadraticDiscriminantAnalysis(priors=None, reg...
# 223                     GaussianNB            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.165500                                          0.004314       GaussianNB(priors=None, var_smoothing=1e-09)
# 139                     GaussianNB             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165500                                          0.004957       GaussianNB(priors=None, var_smoothing=1e-09)
# 268           LogisticRegressionCV            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.165500                                          0.006043  LogisticRegressionCV(Cs=10, class_weight=None,...
# 247           LogisticRegressionCV            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.165500                                          0.006043  LogisticRegressionCV(Cs=10, class_weight=None,...
# 79            LogisticRegressionCV             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.165500                                          0.006443  LogisticRegressionCV(Cs=10, class_weight=None,...
# 58            LogisticRegressionCV             3  [scannedLineItems, scansWithoutRegistration, t...                            0.165500                                          0.006443  LogisticRegressionCV(Cs=10, class_weight=None,...
# 44            KNeighborsClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.165400                                          0.005825  KNeighborsClassifier(algorithm='auto', leaf_si...
# 289           LogisticRegressionCV            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.165300                                          0.005855  LogisticRegressionCV(Cs=10, class_weight=None,...
# 205           LogisticRegressionCV            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.165300                                          0.006654  LogisticRegressionCV(Cs=10, class_weight=None,...
# 24                   SGDClassifier             2                     [scannedLineItems, trustLevel]                            0.165200                                          0.007465  SGDClassifier(alpha=0.0001, average=False, cla...
# 251  QuadraticDiscriminantAnalysis            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.165200                                          0.002914  QuadraticDiscriminantAnalysis(priors=None, reg...
# 97                      GaussianNB             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.005033       GaussianNB(priors=None, var_smoothing=1e-09)
# 118                     GaussianNB             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.005033       GaussianNB(priors=None, var_smoothing=1e-09)
# 160                     GaussianNB             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.004508       GaussianNB(priors=None, var_smoothing=1e-09)
# 181                     GaussianNB             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.165000                                          0.004508       GaussianNB(priors=None, var_smoothing=1e-09)
# 36              LogisticRegression             2                     [scannedLineItems, trustLevel]                            0.165000                                          0.006501  LogisticRegression(C=1.0, class_weight=None, d...
# 100           LogisticRegressionCV             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.006875  LogisticRegressionCV(Cs=10, class_weight=None,...
# 163           LogisticRegressionCV             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.006501  LogisticRegressionCV(Cs=10, class_weight=None,...
# 121           LogisticRegressionCV             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.165000                                          0.006501  LogisticRegressionCV(Cs=10, class_weight=None,...
# 124                     Perceptron             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164900                                          0.003880  Perceptron(alpha=0.0001, class_weight=None, ea...
# 23            KNeighborsClassifier             2                     [scannedLineItems, trustLevel]                            0.164700                                          0.007759  KNeighborsClassifier(algorithm='auto', leaf_si...
# 125  QuadraticDiscriminantAnalysis             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164500                                          0.004536  QuadraticDiscriminantAnalysis(priors=None, reg...
# 83   QuadraticDiscriminantAnalysis             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.164500                                          0.004536  QuadraticDiscriminantAnalysis(priors=None, reg...
# 246             LogisticRegression            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.164500                                          0.006521  LogisticRegression(C=1.0, class_weight=None, d...
# 142           LogisticRegressionCV             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164500                                          0.006893  LogisticRegressionCV(Cs=10, class_weight=None,...
# 184           LogisticRegressionCV             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.164500                                          0.006521  LogisticRegressionCV(Cs=10, class_weight=None,...
# 183             LogisticRegression             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.164500                                          0.006521  LogisticRegression(C=1.0, class_weight=None, d...
# 225             LogisticRegression            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.164500                                          0.006521  LogisticRegression(C=1.0, class_weight=None, d...
# 204             LogisticRegression            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.164500                                          0.006521  LogisticRegression(C=1.0, class_weight=None, d...
# 66                   SGDClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.164200                                          0.006640  SGDClassifier(alpha=0.0001, average=False, cla...
# 63             ExtraTreeClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.164100                                          0.004609  ExtraTreeClassifier(class_weight=None, criteri...
# 146  QuadraticDiscriminantAnalysis             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164000                                          0.004508  QuadraticDiscriminantAnalysis(priors=None, reg...
# 104  QuadraticDiscriminantAnalysis             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164000                                          0.005032  QuadraticDiscriminantAnalysis(priors=None, reg...
# 57              LogisticRegression             3  [scannedLineItems, scansWithoutRegistration, t...                            0.164000                                          0.006501  LogisticRegression(C=1.0, class_weight=None, d...
# 99              LogisticRegression             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.164000                                          0.006501  LogisticRegression(C=1.0, class_weight=None, d...
# 78              LogisticRegression             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.164000                                          0.006501  LogisticRegression(C=1.0, class_weight=None, d...
# 286                     GaussianNB            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.163800                                          0.004136       GaussianNB(priors=None, var_smoothing=1e-09)
# 265                     GaussianNB            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.163800                                          0.004136       GaussianNB(priors=None, var_smoothing=1e-09)
# 244                     GaussianNB            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.163800                                          0.004136       GaussianNB(priors=None, var_smoothing=1e-09)
# 120             LogisticRegression             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.163500                                          0.006443  LogisticRegression(C=1.0, class_weight=None, d...
# 37            LogisticRegressionCV             2                     [scannedLineItems, trustLevel]                            0.163500                                          0.006820  LogisticRegressionCV(Cs=10, class_weight=None,...
# 267             LogisticRegression            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.163500                                          0.006443  LogisticRegression(C=1.0, class_weight=None, d...
# 288             LogisticRegression            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.163500                                          0.006443  LogisticRegression(C=1.0, class_weight=None, d...
# 61                      Perceptron             3  [scannedLineItems, scansWithoutRegistration, t...                            0.163400                                          0.006517  Perceptron(alpha=0.0001, class_weight=None, ea...
# 69     PassiveAggressiveClassifier             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.163200                                          0.006202  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 141             LogisticRegression             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.163200                                          0.006199  LogisticRegression(C=1.0, class_weight=None, d...
# 162             LogisticRegression             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.163200                                          0.006199  LogisticRegression(C=1.0, class_weight=None, d...
# 111    PassiveAggressiveClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.162400                                          0.006661  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 161     LinearDiscriminantAnalysis             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.162200                                          0.005372  LinearDiscriminantAnalysis(n_components=None, ...
# 90     PassiveAggressiveClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.162200                                          0.006311  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 140     LinearDiscriminantAnalysis             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.161700                                          0.005129  LinearDiscriminantAnalysis(n_components=None, ...
# 48     PassiveAggressiveClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.161500                                          0.006214  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 245     LinearDiscriminantAnalysis            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.161200                                          0.005591  LinearDiscriminantAnalysis(n_components=None, ...
# 224     LinearDiscriminantAnalysis            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.161200                                          0.005591  LinearDiscriminantAnalysis(n_components=None, ...
# 182     LinearDiscriminantAnalysis             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.161200                                          0.005591  LinearDiscriminantAnalysis(n_components=None, ...
# 266     LinearDiscriminantAnalysis            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.161200                                          0.005591  LinearDiscriminantAnalysis(n_components=None, ...
# 203     LinearDiscriminantAnalysis            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.161200                                          0.005591  LinearDiscriminantAnalysis(n_components=None, ...
# 77      LinearDiscriminantAnalysis             4  [pricePerScannedLineItem, scannedLineItems, sc...                            0.160999                                          0.006575  LinearDiscriminantAnalysis(n_components=None, ...
# 27     PassiveAggressiveClassifier             2                     [scannedLineItems, trustLevel]                            0.160700                                          0.006839  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 287     LinearDiscriminantAnalysis            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.160700                                          0.006609  LinearDiscriminantAnalysis(n_components=None, ...
# 35      LinearDiscriminantAnalysis             2                     [scannedLineItems, trustLevel]                            0.160500                                          0.006820  LinearDiscriminantAnalysis(n_components=None, ...
# 56      LinearDiscriminantAnalysis             3  [scannedLineItems, scansWithoutRegistration, t...                            0.160499                                          0.007035  LinearDiscriminantAnalysis(n_components=None, ...
# 119     LinearDiscriminantAnalysis             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.160499                                          0.006284  LinearDiscriminantAnalysis(n_components=None, ...
# 98      LinearDiscriminantAnalysis             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.160499                                          0.006284  LinearDiscriminantAnalysis(n_components=None, ...
# 105            ExtraTreeClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.159300                                          0.009176  ExtraTreeClassifier(class_weight=None, criteri...
# 45                   SGDClassifier             3  [scannedLineItems, scansWithoutRegistration, t...                            0.158900                                          0.016179  SGDClassifier(alpha=0.0001, average=False, cla...
# 87                   SGDClassifier             5  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.158398                                          0.024395  SGDClassifier(alpha=0.0001, average=False, cla...
# 0              ExtraTreeClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  ExtraTreeClassifier(class_weight=None, criteri...
# 19                      Perceptron             1                                       [trustLevel]                            0.156000                                          0.006350  Perceptron(alpha=0.0001, class_weight=None, ea...
# 13                      GaussianNB             1                                       [trustLevel]                            0.156000                                          0.006350       GaussianNB(priors=None, var_smoothing=1e-09)
# 1           DecisionTreeClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  DecisionTreeClassifier(class_weight=None, crit...
# 14      LinearDiscriminantAnalysis             1                                       [trustLevel]                            0.156000                                          0.006350  LinearDiscriminantAnalysis(n_components=None, ...
# 15              LogisticRegression             1                                       [trustLevel]                            0.156000                                          0.006350  LogisticRegression(C=1.0, class_weight=None, d...
# 16            LogisticRegressionCV             1                                       [trustLevel]                            0.156000                                          0.006350  LogisticRegressionCV(Cs=10, class_weight=None,...
# 10            ExtraTreesClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  ExtraTreesClassifier(bootstrap=False, class_we...
# 20   QuadraticDiscriminantAnalysis             1                                       [trustLevel]                            0.156000                                          0.006350  QuadraticDiscriminantAnalysis(priors=None, reg...
# 9                BaggingClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  BaggingClassifier(base_estimator=None, bootstr...
# 8       GradientBoostingClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  GradientBoostingClassifier(criterion='friedman...
# 7               AdaBoostClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  AdaBoostClassifier(algorithm='SAMME.R', base_e...
# 6      PassiveAggressiveClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 3                    SGDClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  SGDClassifier(alpha=0.0001, average=False, cla...
# 2             KNeighborsClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  KNeighborsClassifier(algorithm='auto', leaf_si...
# 11          RandomForestClassifier             1                                       [trustLevel]                            0.156000                                          0.006350  RandomForestClassifier(bootstrap=True, class_w...
# 210            ExtraTreeClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.155200                                          0.018975  ExtraTreeClassifier(class_weight=None, criteri...
# 108                  SGDClassifier             6  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.153500                                          0.020774  SGDClassifier(alpha=0.0001, average=False, cla...
# 189            ExtraTreeClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.145700                                          0.032911  ExtraTreeClassifier(class_weight=None, criteri...
# 147            ExtraTreeClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.141999                                          0.029936  ExtraTreeClassifier(class_weight=None, criteri...
# 168            ExtraTreeClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                            0.141300                                          0.027560  ExtraTreeClassifier(class_weight=None, criteri...
# 231            ExtraTreeClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.138901                                          0.032569  ExtraTreeClassifier(class_weight=None, criteri...
# 18                 NearestCentroid             1                                       [trustLevel]                            0.133900                                          0.012512  NearestCentroid(metric='euclidean', shrink_thr...
# 40                      Perceptron             2                     [scannedLineItems, trustLevel]                            0.130500                                          0.112914  Perceptron(alpha=0.0001, class_weight=None, ea...
# 252            ExtraTreeClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                            0.124900                                          0.036140  ExtraTreeClassifier(class_weight=None, criteri...
# 126            ExtraTreeClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                            0.117700                                          0.042844  ExtraTreeClassifier(class_weight=None, criteri...
# 273            ExtraTreeClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                            0.078498                                          0.073358  ExtraTreeClassifier(class_weight=None, criteri...
# 59                   MultinomialNB             3  [scannedLineItems, scansWithoutRegistration, t...                            0.060300                                          0.012569  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 38                   MultinomialNB             2                     [scannedLineItems, trustLevel]                            0.054399                                          0.014581  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 149           KNeighborsClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.073500                                          0.010811  KNeighborsClassifier(algorithm='auto', leaf_si...
# 128           KNeighborsClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.073500                                          0.010811  KNeighborsClassifier(algorithm='auto', leaf_si...
# 258    PassiveAggressiveClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.154100                                          0.037535  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 279    PassiveAggressiveClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -0.161600                                          0.017134  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 153    PassiveAggressiveClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.162002                                          0.028364  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 235              RidgeClassifierCV            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.171900                                          0.000289  RidgeClassifierCV(alphas=array([ 0.1,  1. , 10...
# ...
# 131                RidgeClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  RidgeClassifier(alpha=1.0, class_weight=None, ...
# 138                    BernoulliNB             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 194                RidgeClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.171900                                          0.000289  RidgeClassifier(alpha=1.0, class_weight=None, ...
# 214              RidgeClassifierCV            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.171900                                          0.000289  RidgeClassifierCV(alphas=array([ 0.1,  1. , 10...
# 215                RidgeClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.171900                                          0.000289  RidgeClassifier(alpha=1.0, class_weight=None, ...
# 180                    BernoulliNB             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.171900                                          0.000289  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 109              RidgeClassifierCV             6  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  RidgeClassifierCV(alphas=array([ 0.1,  1. , 10...
# 151              RidgeClassifierCV             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  RidgeClassifierCV(alphas=array([ 0.1,  1. , 10...
# 152                RidgeClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  RidgeClassifier(alpha=1.0, class_weight=None, ...
# 159                    BernoulliNB             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.171900                                          0.000289  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 173                RidgeClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.171900                                          0.000289  RidgeClassifier(alpha=1.0, class_weight=None, ...
# 172              RidgeClassifierCV             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.171900                                          0.000289  RidgeClassifierCV(alphas=array([ 0.1,  1. , 10...
# 243                    BernoulliNB            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.174400                                          0.004103  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 264                    BernoulliNB            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.174400                                          0.004103  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 285                    BernoulliNB            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -0.174400                                          0.004103  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 201                    BernoulliNB            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.174400                                          0.004103  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 222                    BernoulliNB            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.174400                                          0.004103  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# 212           KNeighborsClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.195000                                          0.017436  KNeighborsClassifier(algorithm='auto', leaf_si...
# 170           KNeighborsClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.195000                                          0.017436  KNeighborsClassifier(algorithm='auto', leaf_si...
# 191           KNeighborsClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.195000                                          0.017436  KNeighborsClassifier(algorithm='auto', leaf_si...
# 233           KNeighborsClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.195000                                          0.017436  KNeighborsClassifier(algorithm='auto', leaf_si...
# 174    PassiveAggressiveClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.196600                                          0.174498  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 275           KNeighborsClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -0.198100                                          0.015285  KNeighborsClassifier(algorithm='auto', leaf_si...
# 254           KNeighborsClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.198200                                          0.014549  KNeighborsClassifier(algorithm='auto', leaf_si...
# 171                  SGDClassifier             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.263798                                          0.063216  SGDClassifier(alpha=0.0001, average=False, cla...
# 229                     Perceptron            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.275005                                          0.067465  Perceptron(alpha=0.0001, class_weight=None, ea...
# 166                     Perceptron             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.284201                                          0.074078  Perceptron(alpha=0.0001, class_weight=None, ea...
# 208                     Perceptron            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.284505                                          0.072143  Perceptron(alpha=0.0001, class_weight=None, ea...
# 292                     Perceptron            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -0.329502                                          0.128315  Perceptron(alpha=0.0001, class_weight=None, ea...
# 129                  SGDClassifier             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.343096                                          0.142246  SGDClassifier(alpha=0.0001, average=False, cla...
# 213                  SGDClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.356808                                          0.140032  SGDClassifier(alpha=0.0001, average=False, cla...
# 271                     Perceptron            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.426905                                          0.442874  Perceptron(alpha=0.0001, class_weight=None, ea...
# 234                  SGDClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.462704                                          0.422902  SGDClassifier(alpha=0.0001, average=False, cla...
# 237    PassiveAggressiveClassifier            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.660500                                          1.520236  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 187                     Perceptron             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -0.688505                                          1.129945  Perceptron(alpha=0.0001, class_weight=None, ea...
# 250                     Perceptron            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -0.798485                                          1.272354  Perceptron(alpha=0.0001, class_weight=None, ea...
# 145                     Perceptron             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -0.966203                                          2.081246  Perceptron(alpha=0.0001, class_weight=None, ea...
# 276                  SGDClassifier            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -1.095500                                          2.469443  SGDClassifier(alpha=0.0001, average=False, cla...
# 150                  SGDClassifier             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -1.332892                                          2.171398  SGDClassifier(alpha=0.0001, average=False, cla...
# 80                   MultinomialNB             4  [pricePerScannedLineItem, scannedLineItems, sc...                           -1.674098                                          0.107032  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 216    PassiveAggressiveClassifier            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -1.870700                                          3.498204  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 192                  SGDClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -1.986796                                          5.199244  SGDClassifier(alpha=0.0001, average=False, cla...
# 101                  MultinomialNB             5  [lineItemVoidsPerPosition, pricePerScannedLine...                           -2.006997                                          0.101324  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 143                  MultinomialNB             7  [lineItemVoidsPerPosition, pricePerScannedLine...                           -2.025098                                          0.138404  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 255                  SGDClassifier            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -2.126501                                          4.048281  SGDClassifier(alpha=0.0001, average=False, cla...
# 122                  MultinomialNB             6  [lineItemVoidsPerPosition, pricePerScannedLine...                           -2.161297                                          0.096178  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 164                  MultinomialNB             8  [lineItemVoidsPerPosition, pricePerScannedLine...                           -2.310498                                          0.119712  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 195    PassiveAggressiveClassifier            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -2.398310                                          4.528215  PassiveAggressiveClassifier(C=1.0, average=Fal...
# 185                  MultinomialNB             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -5.864196                                          0.143839  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 206                  MultinomialNB            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                           -5.945896                                          0.144617  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 227                  MultinomialNB            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -5.953896                                          0.145960  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 248                  MultinomialNB            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -5.965396                                          0.148810  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 269                  MultinomialNB            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                           -5.974195                                          0.159910  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 290                  MultinomialNB            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                           -6.011596                                          0.160433  MultinomialNB(alpha=1.0, class_prior=None, fit...
# 60                 NearestCentroid             3  [scannedLineItems, scansWithoutRegistration, t...                           -7.228603                                          0.191686  NearestCentroid(metric='euclidean', shrink_thr...
# 39                 NearestCentroid             2                     [scannedLineItems, trustLevel]                           -7.465602                                          0.176794  NearestCentroid(metric='euclidean', shrink_thr...
# 81                 NearestCentroid             4  [pricePerScannedLineItem, scannedLineItems, sc...                           -7.989603                                          0.227137  NearestCentroid(metric='euclidean', shrink_thr...
# 102                NearestCentroid             5  [lineItemVoidsPerPosition, pricePerScannedLine...                           -7.999103                                          0.223212  NearestCentroid(metric='euclidean', shrink_thr...
# 123                NearestCentroid             6  [lineItemVoidsPerPosition, pricePerScannedLine...                           -8.000603                                          0.223342  NearestCentroid(metric='euclidean', shrink_thr...
# 228                NearestCentroid            11  [grandTotal, lineItemVoidsPerPosition, lineIte...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 186                NearestCentroid             9  [grandTotal, lineItemVoidsPerPosition, pricePe...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 270                NearestCentroid            13  [grandTotal, lineItemVoidsPerPosition, lineIte...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 249                NearestCentroid            12  [grandTotal, lineItemVoidsPerPosition, lineIte...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 291                NearestCentroid            14  [grandTotal, lineItemVoids, lineItemVoidsPerPo...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 207                NearestCentroid            10  [grandTotal, lineItemVoidsPerPosition, pricePe...                          -10.768188                                          0.271015  NearestCentroid(metric='euclidean', shrink_thr...
# 144                NearestCentroid             7  [lineItemVoidsPerPosition, pricePerScannedLine...                          -10.769888                                          0.269941  NearestCentroid(metric='euclidean', shrink_thr...
# 165                NearestCentroid             8  [lineItemVoidsPerPosition, pricePerScannedLine...                          -10.769888                                          0.269941  NearestCentroid(metric='euclidean', shrink_thr...

# %%
def get_monetary_value(cm, y_holdout):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(score, 'for ', len(y_holdout), ' instances in the test set')
        print(score/len(y_holdout), ' per instance in the test set')
        return score
        

bestModel = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
bestFeatureSet = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]

bestModel.fit(X[list(bestFeatureSet)], Y)

cm = confusion_matrix(Y, bestModel.predict(X[list(bestFeatureSet)]))
monetary_value = get_monetary_value(cm, Y)
# Out:
# True negative:  48280
# False positive:  1
# False negative:  0
# True positive:  1719
# 8570 for  50000  instances in the test set
# 0.1714  per instance in the test set

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

best_features = SelectKBest(f_classif, k=1).fit(X,Y)
best_feature_list = X.columns[best_features.get_support()]

#X = X[best_feature_list]

#X.columns

best_feature_list.values
# Out:
# array(['trustLevel'], dtype=object)

# %%
import time

result_table = pd.DataFrame(columns=["Model", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation"])

for model in model_factory:
 
 t = time.time()
# print("Started " + model.__class__.__name__)

 model.seed = 42

 scores = cross_val_score(model, X, Y, cv=skf, scoring=my_custom_score)
 model_name = model.__class__.__name__
 score_mean = scores.mean()
 score_std = scores.std()

# print("Finished " + model.__class__.__name__ + " after " + str(time.time() - t) + " seconds")
# print("Monetary Value Per Instance - Mean " + str(score_mean))
# print("Monetary Value Per Instance - Standard Deviation " + str(score_std))  
# print("")  
    
 result_table = result_table.append({
     "Model": model_name,
     "Monetary Value Per Instance - Mean":  score_mean,
     "Monetary Value Per Instance - Standard Deviation": score_std
      }, ignore_index=True)

       
       
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:716: RuntimeWarning: divide by zero encountered in power
#   X2 = np.dot(Xm, R * (S ** (-0.5)))
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:719: RuntimeWarning: divide by zero encountered in log
#   u = np.asarray([np.sum(np.log(s)) for s in self.scalings_])
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:720: RuntimeWarning: invalid value encountered in add
#   return (-0.5 * (norm2 + u) + np.log(self.priors_))
#                             Model  Monetary Value Per Instance - Mean  \
# 0             ExtraTreeClassifier                            0.141000
# 9               BaggingClassifier                            0.141000
# 19                     Perceptron                            0.141000
# 16           LogisticRegressionCV                            0.141000
# 15             LogisticRegression                            0.141000
# 14     LinearDiscriminantAnalysis                            0.141000
# 13                     GaussianNB                            0.141000
# 11         RandomForestClassifier                            0.141000
# 1          DecisionTreeClassifier                            0.141000
# 10           ExtraTreesClassifier                            0.141000
# 8      GradientBoostingClassifier                            0.141000
# 7              AdaBoostClassifier                            0.141000
# 6     PassiveAggressiveClassifier                            0.141000
# 3                   SGDClassifier                            0.141000
# 2            KNeighborsClassifier                            0.141000
# 18                NearestCentroid                            0.117005
# 12                    BernoulliNB                           -0.164500
# 5                 RidgeClassifier                           -0.164500
# 4               RidgeClassifierCV                           -0.164500
# 17                  MultinomialNB                           -0.164500
# 20  QuadraticDiscriminantAnalysis                           -2.270500
#
#     Monetary Value Per Instance - Standard Deviation
# 0                                           0.025474
# 9                                           0.025474
# 19                                          0.025474
# 16                                          0.025474
# 15                                          0.025474
# 14                                          0.025474
# 13                                          0.025474
# 11                                          0.025474
# 1                                           0.025474
# 10                                          0.025474
# 8                                           0.025474
# 7                                           0.025474
# 6                                           0.025474
# 3                                           0.025474
# 2                                           0.025474
# 18                                          0.030603
# 12                                          0.001447
# 5                                           0.001447
# 4                                           0.001447
# 17                                          0.001447
# 20                                          7.246535
