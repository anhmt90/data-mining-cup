# %%
# %run main.ipynb
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %%
# Table for training results
result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", 
                                     "Optimal Parameters", "Monetary Value Per Instance - Mean", 
                                     "Monetary Value Per Instance - Standard Deviation", 
                                     "Time needed", "Raw Model"])

# %%
from itertools import chain
def get_dict_concat(d1, d2):
    return dict(chain.from_iterable(d.items() for d in (d1, d2)))

# %% [markdown]
# # Model factory -> only KNeighborsClassifier for in-depth analysis

# %%
from sklearn.ensemble.bagging import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors.classification import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline

skf = StratifiedKFold(n_splits=10)

param_bagging = {
#         'bootstrap': [True, False],
#     'bootstrap_features': [True, False],    
    'n_estimators': [50, 120],
#         'warm_start': [True, False],
    'oob_score': [True, False],
}

param_dt = {
    'base_estimator__max_leaf_nodes': [5,10,20,30]
}

param_knn = {
    'base_estimator__n_neighbors' : [15],
    'base_estimator__weights' : ['distance'],
    'base_estimator__p' : [1]
}

param_logistics = {
    'base_estimator__solver' : ['newton-cg'], 
    'base_estimator__C' : [1.2],
    'base_estimator__fit_intercept' : [True],
    'base_estimator__class_weight' : [None, 'balanced'],
    'base_estimator__max_iter': [100000]
}


model_tuning_factory = [
#     GridSearchCV(BaggingClassifier(DecisionTreeClassifier()),
#                  param_grid = get_dict_concat(param_bagging, param_dt), 
#                  cv = skf,
#                  scoring = my_custom_score,
#                  n_jobs = 4
#                  ),
        
    GridSearchCV(BaggingClassifier(LogisticRegression(n_jobs = 4)),
                 param_grid = get_dict_concat(param_bagging, param_logistics), 
                 cv = skf,
                 scoring = my_custom_score,
                 n_jobs = 8
                 ),
    
#     GridSearchCV(BaggingClassifier(KNeighborsClassifier()),
#                  param_grid = get_dict_concat(param_bagging, param_knn), 
#                  cv = skf,
#                  scoring = my_custom_score,
#                  n_jobs = 4
#                  )
]

# %%
run()

# %%
result_table = pd.read_pickle("result_table_BaggingClassifier.pkl")

# %%
result_table = result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
result_table.index = range(0,result_table.shape[0])
result_table
# Out:
#                 Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation  Time needed                                          Raw Model Feature Selection Technique
# 0   BaggingClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.167642                                          0.117763          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 1   BaggingClassifier   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.167642                                          0.118947          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 2   BaggingClassifier        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.167642                                          0.117763          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 3   BaggingClassifier   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.103928          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 4   BaggingClassifier   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.121516          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 5   BaggingClassifier   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.099857          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 6   BaggingClassifier   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.121516          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 7   BaggingClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.121516          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 8   BaggingClassifier   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.162320                                          0.099857          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 9   BaggingClassifier   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.159659                                          0.102456          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 10  BaggingClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.159659                                          0.102456          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 11  BaggingClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.114362          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 12  BaggingClassifier     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 13  BaggingClassifier   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 14  BaggingClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.114362          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 15  BaggingClassifier   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 16  BaggingClassifier     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 17  BaggingClassifier     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 18  BaggingClassifier     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 19  BaggingClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.114362          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 20  BaggingClassifier     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.156998                                          0.126081          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 21  BaggingClassifier   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.104109          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 22  BaggingClassifier        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.103660          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 23  BaggingClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.116517          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 24  BaggingClassifier     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.106808          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 25  BaggingClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.104109          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 26  BaggingClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.114562          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 27  BaggingClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.114562          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 28  BaggingClassifier        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.103660          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 29  BaggingClassifier        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.103660          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 30  BaggingClassifier        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.103660          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 31  BaggingClassifier     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.103660          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 32  BaggingClassifier     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.154337                                          0.102851          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 33  BaggingClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.151676                                          0.132435          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 34  BaggingClassifier     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.151676                                          0.132435          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 35  BaggingClassifier        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.114885          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 36  BaggingClassifier   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.114885          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 37  BaggingClassifier        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.101822          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 38  BaggingClassifier   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.117336          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 39  BaggingClassifier     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.117336          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 40  BaggingClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.114885          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 41  BaggingClassifier     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.114885          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 42  BaggingClassifier        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.117336          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 43  BaggingClassifier     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.120126          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 44  BaggingClassifier        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.149015                                          0.114885          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 45  BaggingClassifier        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.143693                                          0.118304          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 46  BaggingClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.090474                                          0.162155          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 47  BaggingClassifier   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.090474                                          0.162155          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 48  BaggingClassifier     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.077169                                          0.154754          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 49  BaggingClassifier        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator__C': 1.2, 'base_estimator__cl...                            0.071847                                          0.154587          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 50  BaggingClassifier   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.013305                                          0.191173          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 51  BaggingClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.018627                                          0.189988          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 52  BaggingClassifier     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.018627                                          0.190712          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 53  BaggingClassifier        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.018627                                          0.194422          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 54  BaggingClassifier        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.018627                                          0.190712          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 55  BaggingClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.023949                                          0.187882          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 56  BaggingClassifier        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.023949                                          0.193111          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 57  BaggingClassifier   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.023949                                          0.187882          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 58  BaggingClassifier     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.023949                                          0.187882          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 59  BaggingClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.053220                                          0.195173          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 60  BaggingClassifier   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.053220                                          0.195173          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 61  BaggingClassifier   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.053220                                          0.195173          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 62  BaggingClassifier     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.058542                                          0.192915          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 63  BaggingClassifier     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.058542                                          0.192915          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 64  BaggingClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.061203                                          0.195178          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 65  BaggingClassifier     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.061203                                          0.193715          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 66  BaggingClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.066525                                          0.195624          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 67  BaggingClassifier   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.066525                                          0.191217          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 68  BaggingClassifier        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.122406                                          0.202208          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 69  BaggingClassifier        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 70  BaggingClassifier   StandardScaler             2                     [trustLevel, scannedLineItems]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 71  BaggingClassifier        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 72  BaggingClassifier       No Scaling             2                     [trustLevel, scannedLineItems]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 73  BaggingClassifier     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 74  BaggingClassifier        LogScaler             2                     [trustLevel, scannedLineItems]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.141032                                          0.210826          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 75  BaggingClassifier        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.154337                                          0.187638          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 76  BaggingClassifier       No Scaling             1                                       [trustLevel]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.276743                                          0.011709          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 77  BaggingClassifier        LogScaler             1                                       [trustLevel]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.276743                                          0.011709          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 78  BaggingClassifier     MinMaxScaler             1                                       [trustLevel]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.276743                                          0.011709          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest
# 79  BaggingClassifier   StandardScaler             1                                       [trustLevel]  {'base_estimator__C': 1.2, 'base_estimator__cl...                           -0.276743                                          0.011709          NaN  (LogisticRegression(C=1.2, class_weight=None, ...                 SelectKBest

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'quantityModificationsPerEuro']
# {'base_estimator__C': 1.2, 'base_estimator__class_weight': None, 'base_estimator__fit_intercept': True, 'base_estimator__max_iter': 100000, 'base_estimator__solver': 'newton-cg', 'n_estimators': 50, 'oob_score': True}

# %% [markdown]
# # Print performance of best 10 models

# %%
for rank in range(0,11):
    best = BestModel(rank)
    monetary_value = get_monetary_value(best)
    print()
    best.print_best_model()
    print("-----------------------------------------------------------------------------------------------")
# Out:
# True negative:  1771
# False positive:  4
# False negative:  7
# True positive:  97
# 350 for  1879  instances in the test set
# 0.18626929217668972  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'quantityModificationsPerEuro']
# -----------------------------------------------------------------------------------------------
# True negative:  1771
# False positive:  4
# False negative:  7
# True positive:  97
# 350 for  1879  instances in the test set
# 0.18626929217668972  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'quantityModificationsPerEuro']
# -----------------------------------------------------------------------------------------------
# True negative:  1771
# False positive:  4
# False negative:  8
# True positive:  96
# 340 for  1879  instances in the test set
# 0.1809473124002129  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'valuePerSecond' 'lineItemVoidsPerPosition'
#  'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'secondsPerEuro'
#  'lineItemVoidsPerEuro']
# -----------------------------------------------------------------------------------------------
# True negative:  1771
# False positive:  4
# False negative:  7
# True positive:  97
# 350 for  1879  instances in the test set
# 0.18626929217668972  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'scansWithoutRegistrationPerEuro'
#  'quantityModificationsPerEuro']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  7
# True positive:  97
# 325 for  1879  instances in the test set
# 0.1729643427354976  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'lineItemVoidsPerPosition' 'scannedLineItems'
#  'pricePerScannedLineItem' 'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  7
# True positive:  97
# 325 for  1879  instances in the test set
# 0.1729643427354976  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  7
# True positive:  97
# 325 for  1879  instances in the test set
# 0.1729643427354976  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'valuePerSecond' 'lineItemVoidsPerPosition'
#  'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  8
# True positive:  96
# 315 for  1879  instances in the test set
# 0.16764236295902077  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=120, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'lineItemVoidsPerPosition' 'scannedLineItems'
#  'pricePerScannedLineItem' 'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  7
# True positive:  97
# 325 for  1879  instances in the test set
# 0.1729643427354976  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'quantityModificationsPerSecond']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  6
# True positive:  98
# 335 for  1879  instances in the test set
# 0.17828632251197446  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'lineItemVoidsPerEuro' 'scansWithoutRegistrationPerEuro'
#  'quantityModificationsPerEuro']
# -----------------------------------------------------------------------------------------------
# True negative:  1770
# False positive:  5
# False negative:  5
# True positive:  99
# 345 for  1879  instances in the test set
# 0.1836083022884513  per instance in the test set
#
# BaggingClassifier(base_estimator=LogisticRegression(C=1.2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100000, multi_class='ovr',
#           n_jobs=4, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'lineItemVoidsPerEuro' 'scansWithoutRegistrationPerEuro'
#  'quantityModificationsPerEuro']
# -----------------------------------------------------------------------------------------------
