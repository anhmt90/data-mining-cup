# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.naive_bayes import BernoulliNB

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(BernoulliNB(), 
                 dict(
                     alpha = np.arange(0.0, 2.1, 0.2),
                     binarize = np.arange(0.1, 1.05, 0.1),
                     fit_prior = [True, False],
                     class_prior = [None, [0.01, 0.99], [0.1, 0.9], [0.2, 0.8], 
                               [0.5, 0.5,], [0.8, 0.2], [0.9, 0.1], [0.99, 0.01]],
                 ),
                 cv = skf,
                 scoring = my_custom_score,
                 n_jobs = 4),
]


# iterations = 10

# model_tuning_factory_randomized = [
#     RandomizedSearchCV(LogisticRegression(max_iter = 100000), 
#                  dict(# penalty = ['l1','l2'],  # automatic regularization  -> option 'l1' doesnt work with all solvers and leads to errors
#                      solver = ['newton-cg', 'lbfgs', 'liblinear'], 
#                      fit_intercept = [True, False]),
#                     #  solver = ['lbfgs', 'liblinear', 'sag', 'saga']),
#                  cv = skf,
#                  scoring = my_custom_score,
#                       n_iter  = iterations)
# ]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
#              or model.estimator.__class__.__name__ == 'GaussianNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
#          or model.estimator.__class__.__name__ == 'GaussianNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)

# %%
# result_table.to_pickle("result_table_Logistic_Regression.pkl")
result_table = pd.read_pickle("result_table_BernoulliNB.pkl")

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#            Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 73   BernoulliNB     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 2.0, 'binarize': 1.0, 'class_prior':...                           -0.274082                                          0.047994  BernoulliNB(alpha=2.0, binarize=1.0, class_pri...                 SelectKBest
# 32   BernoulliNB       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 2.0, 'binarize': 1.0, 'class_prior':...                           -0.274082                                          0.047994  BernoulliNB(alpha=2.0, binarize=1.0, class_pri...                 SelectKBest
# 114  BernoulliNB   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 2.0, 'binarize': 1.0, 'class_prior':...                           -0.274082                                          0.047994  BernoulliNB(alpha=2.0, binarize=1.0, class_pri...                 SelectKBest
# 106  BernoulliNB   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 107  BernoulliNB   StandardScaler            13  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 108  BernoulliNB   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 109  BernoulliNB   StandardScaler            14  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 110  BernoulliNB   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 111  BernoulliNB   StandardScaler            15  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 112  BernoulliNB   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 113  BernoulliNB   StandardScaler            16  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 0    BernoulliNB       No Scaling             1                                       [trustLevel]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 104  BernoulliNB   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 115  BernoulliNB   StandardScaler            17  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 116  BernoulliNB   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 117  BernoulliNB   StandardScaler            18  [grandTotal, lineItemVoids, scansWithoutRegist...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 118  BernoulliNB   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 119  BernoulliNB   StandardScaler            19  [totalScanTimeInSeconds, grandTotal, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 120  BernoulliNB   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 121  BernoulliNB   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 105  BernoulliNB   StandardScaler            12  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 103  BernoulliNB   StandardScaler            11  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 123  BernoulliNB        LogScaler             1                                       [trustLevel]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 102  BernoulliNB   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 85   BernoulliNB   StandardScaler             2  [quantityModificationsPerSecond, quantityModif...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 86   BernoulliNB   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 87   BernoulliNB   StandardScaler             3  [quantityModificationsPerScannedLineItem, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 88   BernoulliNB   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 89   BernoulliNB   StandardScaler             4  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 90   BernoulliNB   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 91   BernoulliNB   StandardScaler             5  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 92   BernoulliNB   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 93   BernoulliNB   StandardScaler             6  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 94   BernoulliNB   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 95   BernoulliNB   StandardScaler             7  [quantityModifications, scansWithoutRegistrati...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 96   BernoulliNB   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 97   BernoulliNB   StandardScaler             8  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 98   BernoulliNB   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 99   BernoulliNB   StandardScaler             9  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 100  BernoulliNB   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 101  BernoulliNB   StandardScaler            10  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 122  BernoulliNB   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                       RFECV
# 124  BernoulliNB        LogScaler             1                     [quantityModificationsPerEuro]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 83   BernoulliNB   StandardScaler             1                     [quantityModificationsPerEuro]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 125  BernoulliNB        LogScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 146  BernoulliNB        LogScaler            12  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 147  BernoulliNB        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 148  BernoulliNB        LogScaler            13  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 149  BernoulliNB        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 150  BernoulliNB        LogScaler            14  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 151  BernoulliNB        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 152  BernoulliNB        LogScaler            15  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 153  BernoulliNB        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 154  BernoulliNB        LogScaler            16  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 155  BernoulliNB        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 156  BernoulliNB        LogScaler            17  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 157  BernoulliNB        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 158  BernoulliNB        LogScaler            18  [grandTotal, lineItemVoids, scansWithoutRegist...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 159  BernoulliNB        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 160  BernoulliNB        LogScaler            19  [totalScanTimeInSeconds, grandTotal, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 161  BernoulliNB        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 162  BernoulliNB        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 145  BernoulliNB        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 144  BernoulliNB        LogScaler            11  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 143  BernoulliNB        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 133  BernoulliNB        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 126  BernoulliNB        LogScaler             2  [quantityModificationsPerSecond, quantityModif...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 127  BernoulliNB        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 128  BernoulliNB        LogScaler             3  [quantityModificationsPerScannedLineItem, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 129  BernoulliNB        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 130  BernoulliNB        LogScaler             4  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 131  BernoulliNB        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 132  BernoulliNB        LogScaler             5  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 134  BernoulliNB        LogScaler             6  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 142  BernoulliNB        LogScaler            10  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 135  BernoulliNB        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 136  BernoulliNB        LogScaler             7  [quantityModifications, scansWithoutRegistrati...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 137  BernoulliNB        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 138  BernoulliNB        LogScaler             8  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 139  BernoulliNB        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 140  BernoulliNB        LogScaler             9  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 141  BernoulliNB        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 84   BernoulliNB   StandardScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 82   BernoulliNB   StandardScaler             1                                       [trustLevel]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 1    BernoulliNB       No Scaling             1                     [quantityModificationsPerEuro]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 81   BernoulliNB     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                       RFECV
# 22   BernoulliNB       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 23   BernoulliNB       No Scaling            12  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 24   BernoulliNB       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 25   BernoulliNB       No Scaling            13  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 26   BernoulliNB       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 27   BernoulliNB       No Scaling            14  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 28   BernoulliNB       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 29   BernoulliNB       No Scaling            15  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 30   BernoulliNB       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 31   BernoulliNB       No Scaling            16  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 33   BernoulliNB       No Scaling            17  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 34   BernoulliNB       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 35   BernoulliNB       No Scaling            18  [grandTotal, lineItemVoids, scansWithoutRegist...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 36   BernoulliNB       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 37   BernoulliNB       No Scaling            19  [totalScanTimeInSeconds, grandTotal, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 38   BernoulliNB       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 39   BernoulliNB       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 21   BernoulliNB       No Scaling            11  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 20   BernoulliNB       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 19   BernoulliNB       No Scaling            10  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 9    BernoulliNB       No Scaling             5  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 2    BernoulliNB       No Scaling             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 3    BernoulliNB       No Scaling             2  [quantityModificationsPerSecond, quantityModif...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 4    BernoulliNB       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 5    BernoulliNB       No Scaling             3  [quantityModificationsPerScannedLineItem, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 6    BernoulliNB       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 7    BernoulliNB       No Scaling             4  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 8    BernoulliNB       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 10   BernoulliNB       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 18   BernoulliNB       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 11   BernoulliNB       No Scaling             6  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 12   BernoulliNB       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 13   BernoulliNB       No Scaling             7  [quantityModifications, scansWithoutRegistrati...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 14   BernoulliNB       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 15   BernoulliNB       No Scaling             8  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 16   BernoulliNB       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 17   BernoulliNB       No Scaling             9  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 40   BernoulliNB       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                       RFECV
# 41   BernoulliNB     MinMaxScaler             1                                       [trustLevel]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 42   BernoulliNB     MinMaxScaler             1                     [quantityModificationsPerEuro]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 71   BernoulliNB     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 64   BernoulliNB     MinMaxScaler            12  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 65   BernoulliNB     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 66   BernoulliNB     MinMaxScaler            13  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 67   BernoulliNB     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 68   BernoulliNB     MinMaxScaler            14  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 69   BernoulliNB     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 70   BernoulliNB     MinMaxScaler            15  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 72   BernoulliNB     MinMaxScaler            16  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 62   BernoulliNB     MinMaxScaler            11  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 74   BernoulliNB     MinMaxScaler            17  [lineItemVoids, scansWithoutRegistration, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 75   BernoulliNB     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 76   BernoulliNB     MinMaxScaler            18  [grandTotal, lineItemVoids, scansWithoutRegist...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 77   BernoulliNB     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 78   BernoulliNB     MinMaxScaler            19  [totalScanTimeInSeconds, grandTotal, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 79   BernoulliNB     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 80   BernoulliNB     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 63   BernoulliNB     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 61   BernoulliNB     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 43   BernoulliNB     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 51   BernoulliNB     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 44   BernoulliNB     MinMaxScaler             2  [quantityModificationsPerSecond, quantityModif...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 45   BernoulliNB     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 46   BernoulliNB     MinMaxScaler             3  [quantityModificationsPerScannedLineItem, quan...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 47   BernoulliNB     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 48   BernoulliNB     MinMaxScaler             4  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 49   BernoulliNB     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 50   BernoulliNB     MinMaxScaler             5  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 52   BernoulliNB     MinMaxScaler             6  [quantityModifications, quantityModificationsP...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 60   BernoulliNB     MinMaxScaler            10  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 53   BernoulliNB     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 54   BernoulliNB     MinMaxScaler             7  [quantityModifications, scansWithoutRegistrati...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 55   BernoulliNB     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 56   BernoulliNB     MinMaxScaler             8  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 57   BernoulliNB     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 58   BernoulliNB     MinMaxScaler             9  [scansWithoutRegistration, quantityModificatio...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                         RFE
# 59   BernoulliNB     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                 SelectKBest
# 163  BernoulliNB        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0, 'binarize': 0.1, 'class_prior':...                           -0.276743                                          0.011709  BernoulliNB(alpha=0.0, binarize=0.1, class_pri...                       RFECV

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# BernoulliNB(alpha=2.0, binarize=1.0, class_prior=[0.99, 0.01], fit_prior=True)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'scansWithoutRegistrationPerSecond' 'quantityModificationsPerSecond'
#  'secondsPerEuro' 'scansWithoutRegistrationPerEuro'
#  'quantityModificationsPerEuro']
# {'alpha': 2.0, 'binarize': 1.0, 'class_prior': [0.99, 0.01], 'fit_prior': True}

# %%
# coefficients = pd.DataFrame(best_model.coef_[0], best_model_features)
# coefficients.columns = ['Value']
# coefficients

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1774
# False positive:  1
# False negative:  101
# True positive:  3
# -515 for 1879 instances in the test set
# -0.27408195848855776 per instance in the test set
