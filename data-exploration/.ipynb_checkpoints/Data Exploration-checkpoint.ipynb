# %% [markdown]
# | Column name               | Description                                                                            | Value range                                             |
# |---------------------------|----------------------------------------------------------------------------------------|---------------------------------------------------------|
# | trustLevel                | A customer's individual trust level. 6: Highest trustworthiness                        | {1,2,3,4,5,6}                                           |
# | totalScanTimeInSeconds    | Total time in seconds between the first and last product scanned                       | Positive whole number                                   |
# | grandTotal                | Grand total of products scanned                                                        | Positive decimal number with maximum two decimal places |
# | lineItemVoids             | Number of voided scans                                                                 | Positive whole number                                   |
# | scansWithoutRegistration  | Number of attempts to activate the scanner without actually scanning anything          | Positive whole number or 0                              |
# | quantityModification      | Number of modifiedquantities for one of thescanned products                            | Positive whole number or 0                              |
# | scannedLineItemsPerSecond | Average number of scanned products per second                                          | Positive decimal number                                 |
# | valuePerSecond            | Average total value of scanned products per second                                     | Positive decimal number                                 |
# | lineItemVoidsPerPosition  | Average number of item voids per total number of all scanned and notcancelled products | Positive decimal number                                 |
# | fraud                     | Classification as fraud (1)or not fraud (0)                                            | {0,1}                                                   |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)

# %%
data = pd.read_csv("train.csv", sep="|")

# %% [markdown]
# <h1 style="font-size:3em; color:royalblue">Descriptive Statistics</h1>

# %%
data.shape
# Out:
# (1879, 10)

# %%
data.head(10)
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           5                    1054       54.70              7
# 1           3                     108       27.36              5
# 2           3                    1516       62.16              3
# 3           6                    1791       92.31              8
# 4           5                     430       81.53              3
# 5           1                     770       11.09             11
# 6           3                     294       55.63              2
# 7           2                    1545       22.80              0
# 8           6                     962       65.44              7
# 9           2                     725       41.08             10
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
# 5                         5                      2                   0.033766
# 6                         7                      1                   0.037415
# 7                         8                      4                   0.006472
# 8                         0                      2                   0.028067
# 9                         2                      4                   0.037241
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# 1        0.253333                  0.357143      0
# 2        0.041003                  0.230769      0
# 3        0.051541                  0.275862      0
# 4        0.189605                  0.111111      0
# 5        0.014403                  0.423077      1
# 6        0.189218                  0.181818      0
# 7        0.014757                  0.000000      0
# 8        0.068025                  0.259259      0
# 9        0.056662                  0.370370      0

# %%
data.describe()
# Out:
#         trustLevel  totalScanTimeInSeconds   grandTotal  lineItemVoids  \
# count  1879.000000             1879.000000  1879.000000    1879.000000
# mean      3.401809              932.153273    50.864492       5.469931
# std       1.709404              530.144640    28.940202       3.451169
# min       1.000000                2.000000     0.010000       0.000000
# 25%       2.000000              474.500000    25.965000       2.000000
# 50%       3.000000              932.000000    51.210000       5.000000
# 75%       5.000000             1397.000000    77.285000       8.000000
# max       6.000000             1831.000000    99.960000      11.000000
#
#        scansWithoutRegistration  quantityModifications  \
# count               1879.000000            1879.000000
# mean                   4.904204               2.525279
# std                    3.139697               1.695472
# min                    0.000000               0.000000
# 25%                    2.000000               1.000000
# 50%                    5.000000               3.000000
# 75%                    8.000000               4.000000
# max                   10.000000               5.000000
#
#        scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# count                1879.000000     1879.000000               1879.000000
# mean                    0.058138        0.201746                  0.745404
# std                     0.278512        1.242135                  1.327241
# min                     0.000548        0.000007                  0.000000
# 25%                     0.008384        0.027787                  0.160000
# 50%                     0.016317        0.054498                  0.350000
# 75%                     0.032594        0.107313                  0.666667
# max                     6.666667       37.870000                 11.000000
#
#              fraud
# count  1879.000000
# mean      0.055349
# std       0.228720
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
data.fraud.value_counts()
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64

# %% [markdown]
# <h3 style="color:green"> $\Rightarrow$ Only 104 frauds out of 1879 instances </h3>

# %% [markdown]
# <h1 style="font-size:3em; color:royalblue">Handling missing data</h1>

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().any()
# Out:
# trustLevel                   False
# totalScanTimeInSeconds       False
# grandTotal                   False
# lineItemVoids                False
# scansWithoutRegistration     False
# quantityModifications        False
# scannedLineItemsPerSecond    False
# valuePerSecond               False
# lineItemVoidsPerPosition     False
# fraud                        False
# dtype: bool

# %% [markdown]
# <h3 style="color:green"> $\Rightarrow$ There are no NULL values in the data -> no imputation is needed </h3>

# %% [markdown]
# <h1 style="font-size:3em; color:royalblue">Correlation</h1>

# %%
data.corr()
# Out:
#                            trustLevel  totalScanTimeInSeconds  grandTotal  \
# trustLevel                   1.000000                0.025264    0.047656
# totalScanTimeInSeconds       0.025264                1.000000   -0.001230
# grandTotal                   0.047656               -0.001230    1.000000
# lineItemVoids               -0.017312                0.019068    0.006321
# scansWithoutRegistration     0.017296                0.009066   -0.030573
# quantityModifications        0.006506               -0.011415   -0.008163
# scannedLineItemsPerSecond    0.030701               -0.262988   -0.011885
# valuePerSecond               0.027626               -0.208450    0.075679
# lineItemVoidsPerPosition     0.009241               -0.011623   -0.008858
# fraud                       -0.319765                0.110414    0.001421
#
#                            lineItemVoids  scansWithoutRegistration  \
# trustLevel                     -0.017312                  0.017296
# totalScanTimeInSeconds          0.019068                  0.009066
# grandTotal                      0.006321                 -0.030573
# lineItemVoids                   1.000000                 -0.017023
# scansWithoutRegistration       -0.017023                  1.000000
# quantityModifications          -0.007173                  0.018961
# scannedLineItemsPerSecond      -0.004438                 -0.024126
# valuePerSecond                  0.005114                 -0.018844
# lineItemVoidsPerPosition        0.346514                  0.002834
# fraud                           0.063496                  0.074123
#
#                            quantityModifications  scannedLineItemsPerSecond  \
# trustLevel                              0.006506                   0.030701
# totalScanTimeInSeconds                 -0.011415                  -0.262988
# grandTotal                             -0.008163                  -0.011885
# lineItemVoids                          -0.007173                  -0.004438
# scansWithoutRegistration                0.018961                  -0.024126
# quantityModifications                   1.000000                  -0.014880
# scannedLineItemsPerSecond              -0.014880                   1.000000
# valuePerSecond                          0.010548                   0.692152
# lineItemVoidsPerPosition                0.018318                  -0.056316
# fraud                                  -0.000864                  -0.023085
#
#                            valuePerSecond  lineItemVoidsPerPosition     fraud
# trustLevel                       0.027626                  0.009241 -0.319765
# totalScanTimeInSeconds          -0.208450                 -0.011623  0.110414
# grandTotal                       0.075679                 -0.008858  0.001421
# lineItemVoids                    0.005114                  0.346514  0.063496
# scansWithoutRegistration        -0.018844                  0.002834  0.074123
# quantityModifications            0.010548                  0.018318 -0.000864
# scannedLineItemsPerSecond        0.692152                 -0.056316 -0.023085
# valuePerSecond                   1.000000                  0.019886 -0.028873
# lineItemVoidsPerPosition         0.019886                  1.000000 -0.090116
# fraud                           -0.028873                 -0.090116  1.000000

# %%
corr = data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# <h1 style="font-size:3em; color:royalblue">Data distribution</h1>

# %%
sns.pairplot(data)

# %%
data.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbafb2137f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbafaf38e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbafa6c2be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf80e48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf8102b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf80aada0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf8059048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf807d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf807d5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf8051080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf3fe45c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf3f8eb38>]],
#       dtype=object)

# %% [markdown]
# <h1 style="font-size:3em; color:royalblue">Additional exploration</h1>

# %%
data.groupby(['fraud']).mean()['trustLevel'].plot.bar()
plt.xlabel('Fraud')
plt.ylabel('Average Trust Level')
plt.title('Trust Level as an indicator for fraud')
plt.savefig('Trust Level Fraud.jpg')
